# %%
import os
import torch
import torch.nn.functional as F
from torch.optim import Adam
from tqdm.auto import tqdm, trange
import argparse
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from dataset_swat import ForecastSimpleDataloader
from code_test import test
from copy_transformer import TimeSeriesTransformerGSL

import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler
from fddbenchmark import FDDDataset
from dataset3 import ForecastFDDDataloader
import numpy as np
from tqdm.auto import tqdm, trange

# %%
model = TimeSeriesTransformerGSL(
        ts_dim=51,
        window_size=100,
        d_model=256,
        nhead=8,
        num_layers=2,
        dim_feedforward=128,
        dropout=0.2,
        gsl_k=7,
        n_gnn=1,
        n_hidden=256,
        device='cpu',
    )

# %%
m = torch.load('/home/akozhevnikov/graphs/ts2/saved_models/swat_transformer_gsl_base.pt', weights_only=True)
model.load_state_dict(m)
# Out:
# <All keys matched successfully>

# %%
df_att  = pd.read_csv('SWaT_Dataset_Attack_v0.csv')
feature_cols = [c for c in df_att.columns if c not in ['Timestamp', 'Normal/Attack']]

df_norm = pd.read_csv('SWaT_Dataset_Normal_v0.csv')
scaler = StandardScaler()
scaler.fit(df_norm[feature_cols])

df_test = df_att
df_test[feature_cols] = df_att[feature_cols].astype('float32')
df_test[feature_cols] = scaler.transform(df_test[feature_cols])

df_test['Normal/Attack'] = df_test['Normal/Attack'].apply(lambda x: 0 if x=='Normal' else 1)

# %%
test_dl = ForecastSimpleDataloader(
    dataframe=df_test,
    window_size=100,
    step_size=1,
    use_minibatches=True,
    batch_size=512,
    shuffle=False,
    data_framework='torch',
    device='cpu',
    train=False,             # используем все окна, в том числе с атаками
    timestamp_col='Timestamp',
    label_col='Normal/Attack',
    disable_index=False
)

# %%
all_errors = []
all_true_labels = []
all_errors_vec = []

for i in range(len(test_dl) - 1):
    ts_batch, _, target_batch, label = test_dl[i]
    pred = model(ts_batch)

    target_raw = scaler.inverse_transform(target_batch.cpu().detach().numpy())
    pred_raw = scaler.inverse_transform(pred.cpu().detach().numpy())

    errors = target_raw - pred_raw
    all_errors_vec.extend(errors)
    all_errors.extend(abs(errors).mean(axis=1))
    all_true_labels.extend(label)

# %%
all_errors_vec[0].shape
# Out:
# (51,)

# %%
t = np.mean(all_errors) + np.array(all_errors).std() * 2
ans = (np.array(all_errors) > t).astype('int')
print(classification_report(all_true_labels, ans))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97    394915
#            1       1.00      0.59      0.74     54621
#
#     accuracy                           0.95    449536
#    macro avg       0.97      0.79      0.85    449536
# weighted avg       0.95      0.95      0.94    449536

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, classification_report, f1_score

all_errors = np.stack(all_errors_vec)
all_true_labels = np.array(all_true_labels)

X_train, X_test, y_train, y_test = train_test_split(
    all_errors, all_true_labels,
    test_size=1-0.00667,
    shuffle=True, 
    random_state=42,
)

# %%
from catboost import CatBoostClassifier
c = CatBoostClassifier(iterations=10000, early_stopping_rounds=5, class_weights=(0.05, 0.95))
c.fit(X_train, y_train)
pred = c.predict(X_test)
# Out:
# Learning rate set to 0.001993
# 0:	learn: 0.6895734	total: 2.25ms	remaining: 22.5s
# 1:	learn: 0.6861469	total: 3.41ms	remaining: 17s
# 2:	learn: 0.6825281	total: 4.52ms	remaining: 15.1s
# 3:	learn: 0.6790939	total: 5.61ms	remaining: 14s
# 4:	learn: 0.6761249	total: 6.69ms	remaining: 13.4s
# 5:	learn: 0.6731415	total: 7.78ms	remaining: 13s
# 6:	learn: 0.6701506	total: 8.86ms	remaining: 12.7s
# 7:	learn: 0.6668719	total: 9.97ms	remaining: 12.5s
# 8:	learn: 0.6636076	total: 11.1ms	remaining: 12.3s
# 9:	learn: 0.6611389	total: 12.2ms	remaining: 12.2s
# 10:	learn: 0.6581808	total: 13.3ms	remaining: 12.1s
# 11:	learn: 0.6550325	total: 14.4ms	remaining: 12s
# 12:	learn: 0.6525065	total: 15.4ms	remaining: 11.9s
# 13:	learn: 0.6491523	total: 16.5ms	remaining: 11.8s
# 14:	learn: 0.6460361	total: 17.5ms	remaining: 11.7s
# 15:	learn: 0.6431640	total: 18.6ms	remaining: 11.6s
# 16:	learn: 0.6403043	total: 19.6ms	remaining: 11.5s
# 17:	learn: 0.6374017	total: 20.7ms	remaining: 11.5s
# 18:	learn: 0.6343811	total: 21.7ms	remaining: 11.4s
# 19:	learn: 0.6314755	total: 22.7ms	remaining: 11.3s
# 20:	learn: 0.6288462	total: 23.8ms	remaining: 11.3s
# 21:	learn: 0.6259085	total: 24.8ms	remaining: 11.3s
# 22:	learn: 0.6233609	total: 25.9ms	remaining: 11.2s
# 23:	learn: 0.6205444	total: 27ms	remaining: 11.2s
# 24:	learn: 0.6174724	total: 28ms	remaining: 11.2s
# 25:	learn: 0.6145526	total: 29ms	remaining: 11.1s
# 26:	learn: 0.6115588	total: 30.1ms	remaining: 11.1s
# 27:	learn: 0.6087229	total: 31.1ms	remaining: 11.1s
# 28:	learn: 0.6060776	total: 32.1ms	remaining: 11s
# 29:	learn: 0.6036022	total: 33.1ms	remaining: 11s
# 30:	learn: 0.6013671	total: 34.2ms	remaining: 11s
# 31:	learn: 0.5985477	total: 35.2ms	remaining: 11s
# 32:	learn: 0.5959505	total: 36.2ms	remaining: 10.9s
# 33:	learn: 0.5934448	total: 37.3ms	remaining: 10.9s
# 34:	learn: 0.5905655	total: 38.4ms	remaining: 10.9s
# 35:	learn: 0.5885326	total: 39.4ms	remaining: 10.9s
# 36:	learn: 0.5863259	total: 40.5ms	remaining: 10.9s
# 37:	learn: 0.5837926	total: 41.5ms	remaining: 10.9s
# 38:	learn: 0.5812485	total: 42.5ms	remaining: 10.9s
# 39:	learn: 0.5786734	total: 43.5ms	remaining: 10.8s
# 40:	learn: 0.5760885	total: 44.6ms	remaining: 10.8s
# 41:	learn: 0.5733653	total: 45.7ms	remaining: 10.8s
# 42:	learn: 0.5716852	total: 46.7ms	remaining: 10.8s
# 43:	learn: 0.5693742	total: 47.7ms	remaining: 10.8s
# 44:	learn: 0.5671303	total: 48.7ms	remaining: 10.8s
# 45:	learn: 0.5649129	total: 51.1ms	remaining: 11.1s
# 46:	learn: 0.5626441	total: 52.2ms	remaining: 11.1s
# 47:	learn: 0.5605180	total: 53.3ms	remaining: 11s
# 48:	learn: 0.5581027	total: 54.4ms	remaining: 11.1s
# 49:	learn: 0.5555850	total: 55.5ms	remaining: 11s
# 50:	learn: 0.5536977	total: 56.5ms	remaining: 11s
# 51:	learn: 0.5517732	total: 57.6ms	remaining: 11s
# 52:	learn: 0.5492218	total: 58.6ms	remaining: 11s
# 53:	learn: 0.5469381	total: 59.6ms	remaining: 11s
# 54:	learn: 0.5442997	total: 60.6ms	remaining: 11s
# 55:	learn: 0.5423236	total: 61.7ms	remaining: 11s
# 56:	learn: 0.5403004	total: 62.7ms	remaining: 10.9s
# 57:	learn: 0.5378445	total: 63.7ms	remaining: 10.9s
# 58:	learn: 0.5355754	total: 64.7ms	remaining: 10.9s
# 59:	learn: 0.5336466	total: 65.7ms	remaining: 10.9s
# 60:	learn: 0.5314355	total: 66.8ms	remaining: 10.9s
# 61:	learn: 0.5292977	total: 67.8ms	remaining: 10.9s
# 62:	learn: 0.5272839	total: 68.8ms	remaining: 10.9s
# 63:	learn: 0.5257433	total: 69.8ms	remaining: 10.8s
# 64:	learn: 0.5237672	total: 70.9ms	remaining: 10.8s
# 65:	learn: 0.5215994	total: 71.9ms	remaining: 10.8s
# 66:	learn: 0.5194709	total: 72.9ms	remaining: 10.8s
# 67:	learn: 0.5172882	total: 74ms	remaining: 10.8s
# 68:	learn: 0.5152443	total: 75ms	remaining: 10.8s
# 69:	learn: 0.5134111	total: 76.1ms	remaining: 10.8s
# 70:	learn: 0.5115687	total: 77.1ms	remaining: 10.8s
# 71:	learn: 0.5096796	total: 78.2ms	remaining: 10.8s
# 72:	learn: 0.5076518	total: 79.2ms	remaining: 10.8s
# 73:	learn: 0.5054770	total: 80.2ms	remaining: 10.8s
# 74:	learn: 0.5036205	total: 81.3ms	remaining: 10.8s
# 75:	learn: 0.5015905	total: 82.4ms	remaining: 10.8s
# 76:	learn: 0.4996986	total: 83.4ms	remaining: 10.8s
# 77:	learn: 0.4979943	total: 84.5ms	remaining: 10.7s
# 78:	learn: 0.4962111	total: 85.5ms	remaining: 10.7s
# 79:	learn: 0.4943130	total: 86.6ms	remaining: 10.7s
# 80:	learn: 0.4926906	total: 87.6ms	remaining: 10.7s
# 81:	learn: 0.4908874	total: 88.6ms	remaining: 10.7s
# 82:	learn: 0.4890613	total: 89.6ms	remaining: 10.7s
# 83:	learn: 0.4872065	total: 90.7ms	remaining: 10.7s
# 84:	learn: 0.4856157	total: 91.7ms	remaining: 10.7s
# 85:	learn: 0.4836917	total: 92.8ms	remaining: 10.7s
# 86:	learn: 0.4818514	total: 93.8ms	remaining: 10.7s
# 87:	learn: 0.4802316	total: 94.9ms	remaining: 10.7s
# 88:	learn: 0.4783993	total: 95.9ms	remaining: 10.7s
# 89:	learn: 0.4765060	total: 97ms	remaining: 10.7s
# 90:	learn: 0.4746544	total: 98ms	remaining: 10.7s
# 91:	learn: 0.4729853	total: 99.1ms	remaining: 10.7s
# 92:	learn: 0.4713279	total: 100ms	remaining: 10.7s
# 93:	learn: 0.4700285	total: 101ms	remaining: 10.7s
# 94:	learn: 0.4684013	total: 102ms	remaining: 10.7s
# 95:	learn: 0.4668188	total: 103ms	remaining: 10.7s
# 96:	learn: 0.4656761	total: 105ms	remaining: 10.7s
# 97:	learn: 0.4639989	total: 106ms	remaining: 10.7s
# 98:	learn: 0.4626265	total: 107ms	remaining: 10.7s
# 99:	learn: 0.4609439	total: 108ms	remaining: 10.7s
# 100:	learn: 0.4595440	total: 109ms	remaining: 10.7s
# 101:	learn: 0.4577691	total: 110ms	remaining: 10.7s
# 102:	learn: 0.4563809	total: 111ms	remaining: 10.7s
# 103:	learn: 0.4548809	total: 112ms	remaining: 10.6s
# 104:	learn: 0.4535557	total: 113ms	remaining: 10.7s
# 105:	learn: 0.4519144	total: 114ms	remaining: 10.7s
# 106:	learn: 0.4502439	total: 115ms	remaining: 10.6s
# 107:	learn: 0.4488433	total: 116ms	remaining: 10.6s
# 108:	learn: 0.4474284	total: 117ms	remaining: 10.6s
# 109:	learn: 0.4458971	total: 118ms	remaining: 10.6s
# 110:	learn: 0.4443897	total: 119ms	remaining: 10.6s
# 111:	learn: 0.4430381	total: 120ms	remaining: 10.6s
# 112:	learn: 0.4421004	total: 121ms	remaining: 10.6s
# 113:	learn: 0.4408908	total: 123ms	remaining: 10.6s
# 114:	learn: 0.4394739	total: 124ms	remaining: 10.6s
# 115:	learn: 0.4378903	total: 125ms	remaining: 10.6s
# 116:	learn: 0.4369412	total: 126ms	remaining: 10.6s
# 117:	learn: 0.4356363	total: 127ms	remaining: 10.6s
# 118:	learn: 0.4347437	total: 128ms	remaining: 10.6s
# 119:	learn: 0.4334607	total: 129ms	remaining: 10.6s
# 120:	learn: 0.4322195	total: 130ms	remaining: 10.6s
# 121:	learn: 0.4309310	total: 131ms	remaining: 10.6s
# 122:	learn: 0.4297697	total: 132ms	remaining: 10.6s
# 123:	learn: 0.4283216	total: 133ms	remaining: 10.6s
# 124:	learn: 0.4268405	total: 134ms	remaining: 10.6s
# 125:	learn: 0.4256727	total: 135ms	remaining: 10.6s
# 126:	learn: 0.4247014	total: 136ms	remaining: 10.6s
# 127:	learn: 0.4234275	total: 137ms	remaining: 10.6s
# 128:	learn: 0.4219555	total: 138ms	remaining: 10.6s
# 129:	learn: 0.4207927	total: 139ms	remaining: 10.6s
# 130:	learn: 0.4199769	total: 140ms	remaining: 10.6s
# 131:	learn: 0.4189125	total: 141ms	remaining: 10.6s
# 132:	learn: 0.4176409	total: 142ms	remaining: 10.6s
# 133:	learn: 0.4164450	total: 143ms	remaining: 10.5s
# 134:	learn: 0.4152269	total: 144ms	remaining: 10.5s
# 135:	learn: 0.4140376	total: 145ms	remaining: 10.5s
# 136:	learn: 0.4130210	total: 146ms	remaining: 10.5s
# 137:	learn: 0.4121840	total: 147ms	remaining: 10.5s
# 138:	learn: 0.4111100	total: 148ms	remaining: 10.5s
# 139:	learn: 0.4098650	total: 149ms	remaining: 10.5s
# 140:	learn: 0.4086664	total: 151ms	remaining: 10.5s
# 141:	learn: 0.4076404	total: 152ms	remaining: 10.5s
# 142:	learn: 0.4066907	total: 153ms	remaining: 10.5s
# 143:	learn: 0.4054622	total: 154ms	remaining: 10.5s
# 144:	learn: 0.4041508	total: 155ms	remaining: 10.5s
# 145:	learn: 0.4031024	total: 157ms	remaining: 10.6s
# 146:	learn: 0.4019928	total: 159ms	remaining: 10.6s
# 147:	learn: 0.4010451	total: 160ms	remaining: 10.6s
# 148:	learn: 0.3999561	total: 161ms	remaining: 10.6s
# 149:	learn: 0.3991028	total: 162ms	remaining: 10.6s
# 150:	learn: 0.3982164	total: 163ms	remaining: 10.6s
# 151:	learn: 0.3972186	total: 164ms	remaining: 10.6s
# 152:	learn: 0.3961695	total: 165ms	remaining: 10.6s
# 153:	learn: 0.3950729	total: 166ms	remaining: 10.6s
# 154:	learn: 0.3940075	total: 167ms	remaining: 10.6s
# 155:	learn: 0.3930693	total: 168ms	remaining: 10.6s
# 156:	learn: 0.3923506	total: 169ms	remaining: 10.6s
# 157:	learn: 0.3914463	total: 170ms	remaining: 10.6s
# 158:	learn: 0.3903632	total: 171ms	remaining: 10.6s
# 159:	learn: 0.3892177	total: 172ms	remaining: 10.6s
# 160:	learn: 0.3880257	total: 173ms	remaining: 10.6s
# 161:	learn: 0.3868907	total: 174ms	remaining: 10.6s
# 162:	learn: 0.3861099	total: 175ms	remaining: 10.6s
# 163:	learn: 0.3852354	total: 176ms	remaining: 10.6s
# 164:	learn: 0.3842068	total: 177ms	remaining: 10.6s
# 165:	learn: 0.3834238	total: 178ms	remaining: 10.6s
# 166:	learn: 0.3826583	total: 179ms	remaining: 10.6s
# 167:	learn: 0.3816798	total: 180ms	remaining: 10.6s
# 168:	learn: 0.3805983	total: 182ms	remaining: 10.6s
# 169:	learn: 0.3796576	total: 183ms	remaining: 10.6s
# 170:	learn: 0.3789817	total: 184ms	remaining: 10.6s
# 171:	learn: 0.3780545	total: 185ms	remaining: 10.5s
# 172:	learn: 0.3771458	total: 186ms	remaining: 10.5s
# 173:	learn: 0.3763321	total: 187ms	remaining: 10.5s
# 174:	learn: 0.3756132	total: 188ms	remaining: 10.5s
# 175:	learn: 0.3746214	total: 189ms	remaining: 10.5s
# 176:	learn: 0.3738002	total: 190ms	remaining: 10.5s
# 177:	learn: 0.3731949	total: 191ms	remaining: 10.5s
# 178:	learn: 0.3725075	total: 192ms	remaining: 10.5s
# 179:	learn: 0.3715302	total: 193ms	remaining: 10.5s
# 180:	learn: 0.3706410	total: 194ms	remaining: 10.5s
# 181:	learn: 0.3696768	total: 195ms	remaining: 10.5s
# 182:	learn: 0.3691965	total: 196ms	remaining: 10.5s
# 183:	learn: 0.3687128	total: 197ms	remaining: 10.5s
# 184:	learn: 0.3676565	total: 198ms	remaining: 10.5s
# 185:	learn: 0.3667672	total: 199ms	remaining: 10.5s
# 186:	learn: 0.3659262	total: 200ms	remaining: 10.5s
# 187:	learn: 0.3651456	total: 202ms	remaining: 10.5s
# 188:	learn: 0.3644228	total: 203ms	remaining: 10.5s
# 189:	learn: 0.3634886	total: 204ms	remaining: 10.5s
# 190:	learn: 0.3627870	total: 205ms	remaining: 10.5s
# 191:	learn: 0.3621183	total: 206ms	remaining: 10.5s
# 192:	learn: 0.3612426	total: 207ms	remaining: 10.5s
# 193:	learn: 0.3604063	total: 208ms	remaining: 10.5s
# 194:	learn: 0.3598325	total: 209ms	remaining: 10.5s
# 195:	learn: 0.3590601	total: 210ms	remaining: 10.5s
# 196:	learn: 0.3582223	total: 211ms	remaining: 10.5s
# 197:	learn: 0.3573027	total: 212ms	remaining: 10.5s
# 198:	learn: 0.3566247	total: 213ms	remaining: 10.5s
# 199:	learn: 0.3559033	total: 214ms	remaining: 10.5s
# 200:	learn: 0.3550521	total: 215ms	remaining: 10.5s
# 201:	learn: 0.3541841	total: 217ms	remaining: 10.5s
# 202:	learn: 0.3534919	total: 218ms	remaining: 10.5s
# 203:	learn: 0.3527061	total: 219ms	remaining: 10.5s
# 204:	learn: 0.3520509	total: 220ms	remaining: 10.5s
# 205:	learn: 0.3511187	total: 221ms	remaining: 10.5s
# 206:	learn: 0.3504821	total: 222ms	remaining: 10.5s
# 207:	learn: 0.3498472	total: 223ms	remaining: 10.5s
# 208:	learn: 0.3492355	total: 224ms	remaining: 10.5s
# 209:	learn: 0.3485157	total: 225ms	remaining: 10.5s
# 210:	learn: 0.3477458	total: 226ms	remaining: 10.5s
# 211:	learn: 0.3471588	total: 227ms	remaining: 10.5s
# 212:	learn: 0.3465257	total: 228ms	remaining: 10.5s
# 213:	learn: 0.3458090	total: 229ms	remaining: 10.5s
# 214:	learn: 0.3452234	total: 230ms	remaining: 10.5s
# 215:	learn: 0.3444158	total: 231ms	remaining: 10.5s
# 216:	learn: 0.3439518	total: 232ms	remaining: 10.5s
# 217:	learn: 0.3434196	total: 233ms	remaining: 10.5s
# 218:	learn: 0.3426635	total: 234ms	remaining: 10.5s
# 219:	learn: 0.3418138	total: 235ms	remaining: 10.5s
# 220:	learn: 0.3412008	total: 236ms	remaining: 10.5s
# 221:	learn: 0.3404828	total: 237ms	remaining: 10.4s
# 222:	learn: 0.3399998	total: 238ms	remaining: 10.4s
# 223:	learn: 0.3394023	total: 239ms	remaining: 10.4s
# 224:	learn: 0.3387929	total: 240ms	remaining: 10.4s
# 225:	learn: 0.3383103	total: 241ms	remaining: 10.4s
# 226:	learn: 0.3375325	total: 242ms	remaining: 10.4s
# 227:	learn: 0.3367527	total: 243ms	remaining: 10.4s
# 228:	learn: 0.3360876	total: 244ms	remaining: 10.4s
# 229:	learn: 0.3353092	total: 245ms	remaining: 10.4s
# 230:	learn: 0.3345873	total: 246ms	remaining: 10.4s
# 231:	learn: 0.3339210	total: 247ms	remaining: 10.4s
# 232:	learn: 0.3333231	total: 249ms	remaining: 10.4s
# 233:	learn: 0.3325994	total: 250ms	remaining: 10.4s
# 234:	learn: 0.3319829	total: 251ms	remaining: 10.4s
# 235:	learn: 0.3315637	total: 252ms	remaining: 10.4s
# 236:	learn: 0.3310829	total: 253ms	remaining: 10.4s
# 237:	learn: 0.3303224	total: 254ms	remaining: 10.4s
# 238:	learn: 0.3297804	total: 255ms	remaining: 10.4s
# 239:	learn: 0.3291767	total: 256ms	remaining: 10.4s
# 240:	learn: 0.3285361	total: 257ms	remaining: 10.4s
# 241:	learn: 0.3279025	total: 258ms	remaining: 10.4s
# 242:	learn: 0.3272531	total: 259ms	remaining: 10.4s
# 243:	learn: 0.3268075	total: 260ms	remaining: 10.4s
# 244:	learn: 0.3261867	total: 261ms	remaining: 10.4s
# 245:	learn: 0.3254911	total: 262ms	remaining: 10.4s
# 246:	learn: 0.3250500	total: 263ms	remaining: 10.4s
# 247:	learn: 0.3244230	total: 264ms	remaining: 10.4s
# 248:	learn: 0.3236590	total: 265ms	remaining: 10.4s
# 249:	learn: 0.3231616	total: 268ms	remaining: 10.4s
# 250:	learn: 0.3226565	total: 269ms	remaining: 10.4s
# 251:	learn: 0.3219934	total: 270ms	remaining: 10.4s
# 252:	learn: 0.3215530	total: 271ms	remaining: 10.4s
# 253:	learn: 0.3209063	total: 272ms	remaining: 10.4s
# 254:	learn: 0.3203999	total: 273ms	remaining: 10.4s
# 255:	learn: 0.3198058	total: 274ms	remaining: 10.4s
# 256:	learn: 0.3191869	total: 275ms	remaining: 10.4s
# 257:	learn: 0.3186362	total: 276ms	remaining: 10.4s
# 258:	learn: 0.3179084	total: 277ms	remaining: 10.4s
# 259:	learn: 0.3173149	total: 278ms	remaining: 10.4s
# 260:	learn: 0.3168003	total: 279ms	remaining: 10.4s
# 261:	learn: 0.3163037	total: 280ms	remaining: 10.4s
# 262:	learn: 0.3157266	total: 281ms	remaining: 10.4s
# 263:	learn: 0.3152921	total: 282ms	remaining: 10.4s
# 264:	learn: 0.3149192	total: 283ms	remaining: 10.4s
# 265:	learn: 0.3143224	total: 284ms	remaining: 10.4s
# 266:	learn: 0.3138739	total: 285ms	remaining: 10.4s
# 267:	learn: 0.3133972	total: 287ms	remaining: 10.4s
# 268:	learn: 0.3129421	total: 288ms	remaining: 10.4s
# 269:	learn: 0.3122885	total: 289ms	remaining: 10.4s
# 270:	learn: 0.3118846	total: 290ms	remaining: 10.4s
# 271:	learn: 0.3113320	total: 291ms	remaining: 10.4s
# 272:	learn: 0.3109324	total: 292ms	remaining: 10.4s
# 273:	learn: 0.3103214	total: 293ms	remaining: 10.4s
# 274:	learn: 0.3097323	total: 294ms	remaining: 10.4s
# 275:	learn: 0.3091794	total: 295ms	remaining: 10.4s
# 276:	learn: 0.3088147	total: 296ms	remaining: 10.4s
# 277:	learn: 0.3082857	total: 297ms	remaining: 10.4s
# 278:	learn: 0.3078053	total: 298ms	remaining: 10.4s
# 279:	learn: 0.3073896	total: 299ms	remaining: 10.4s
# 280:	learn: 0.3070323	total: 300ms	remaining: 10.4s
# 281:	learn: 0.3066262	total: 301ms	remaining: 10.4s
# 282:	learn: 0.3061761	total: 302ms	remaining: 10.4s
# 283:	learn: 0.3056426	total: 303ms	remaining: 10.4s
# 284:	learn: 0.3052810	total: 304ms	remaining: 10.3s
# 285:	learn: 0.3047275	total: 305ms	remaining: 10.3s
# 286:	learn: 0.3041684	total: 306ms	remaining: 10.3s
# 287:	learn: 0.3037987	total: 307ms	remaining: 10.3s
# 288:	learn: 0.3034308	total: 308ms	remaining: 10.3s
# 289:	learn: 0.3028600	total: 309ms	remaining: 10.3s
# 290:	learn: 0.3023189	total: 310ms	remaining: 10.3s
# 291:	learn: 0.3018344	total: 311ms	remaining: 10.3s
# 292:	learn: 0.3013812	total: 312ms	remaining: 10.3s
# 293:	learn: 0.3008995	total: 314ms	remaining: 10.4s
# 294:	learn: 0.3004435	total: 315ms	remaining: 10.4s
# 295:	learn: 0.3000649	total: 316ms	remaining: 10.4s
# 296:	learn: 0.2996099	total: 317ms	remaining: 10.4s
# 297:	learn: 0.2992513	total: 318ms	remaining: 10.4s
# 298:	learn: 0.2987212	total: 319ms	remaining: 10.4s
# 299:	learn: 0.2982940	total: 320ms	remaining: 10.4s
# 300:	learn: 0.2978096	total: 322ms	remaining: 10.4s
# 301:	learn: 0.2972922	total: 323ms	remaining: 10.4s
# 302:	learn: 0.2969592	total: 324ms	remaining: 10.4s
# 303:	learn: 0.2966294	total: 325ms	remaining: 10.4s
# 304:	learn: 0.2962172	total: 326ms	remaining: 10.4s
# 305:	learn: 0.2957693	total: 327ms	remaining: 10.3s
# 306:	learn: 0.2952912	total: 328ms	remaining: 10.3s
# 307:	learn: 0.2948995	total: 329ms	remaining: 10.3s
# 308:	learn: 0.2942876	total: 330ms	remaining: 10.3s
# 309:	learn: 0.2937744	total: 331ms	remaining: 10.3s
# 310:	learn: 0.2934482	total: 332ms	remaining: 10.3s
# 311:	learn: 0.2931642	total: 333ms	remaining: 10.3s
# 312:	learn: 0.2927380	total: 334ms	remaining: 10.3s
# 313:	learn: 0.2922328	total: 335ms	remaining: 10.3s
# 314:	learn: 0.2918707	total: 336ms	remaining: 10.3s
# 315:	learn: 0.2915953	total: 337ms	remaining: 10.3s
# 316:	learn: 0.2910662	total: 338ms	remaining: 10.3s
# 317:	learn: 0.2905828	total: 339ms	remaining: 10.3s
# 318:	learn: 0.2901003	total: 340ms	remaining: 10.3s
# 319:	learn: 0.2896483	total: 341ms	remaining: 10.3s
# 320:	learn: 0.2892221	total: 342ms	remaining: 10.3s
# 321:	learn: 0.2889334	total: 343ms	remaining: 10.3s
# 322:	learn: 0.2885440	total: 344ms	remaining: 10.3s
# 323:	learn: 0.2882017	total: 346ms	remaining: 10.3s
# 324:	learn: 0.2878360	total: 347ms	remaining: 10.3s
# 325:	learn: 0.2875664	total: 348ms	remaining: 10.3s
# 326:	learn: 0.2871655	total: 349ms	remaining: 10.3s
# 327:	learn: 0.2868756	total: 350ms	remaining: 10.3s
# 328:	learn: 0.2864034	total: 351ms	remaining: 10.3s
# 329:	learn: 0.2860896	total: 352ms	remaining: 10.3s
# 330:	learn: 0.2855564	total: 353ms	remaining: 10.3s
# 331:	learn: 0.2851881	total: 354ms	remaining: 10.3s
# 332:	learn: 0.2848722	total: 355ms	remaining: 10.3s
# 333:	learn: 0.2844331	total: 356ms	remaining: 10.3s
# 334:	learn: 0.2839763	total: 361ms	remaining: 10.4s
# 335:	learn: 0.2835541	total: 362ms	remaining: 10.4s
# 336:	learn: 0.2832855	total: 363ms	remaining: 10.4s
# 337:	learn: 0.2828602	total: 364ms	remaining: 10.4s
# 338:	learn: 0.2824900	total: 365ms	remaining: 10.4s
# 339:	learn: 0.2819650	total: 367ms	remaining: 10.4s
# 340:	learn: 0.2816542	total: 368ms	remaining: 10.4s
# 341:	learn: 0.2812348	total: 369ms	remaining: 10.4s
# 342:	learn: 0.2809898	total: 370ms	remaining: 10.4s
# 343:	learn: 0.2806198	total: 371ms	remaining: 10.4s
# 344:	learn: 0.2802383	total: 372ms	remaining: 10.4s
# 345:	learn: 0.2798761	total: 373ms	remaining: 10.4s
# 346:	learn: 0.2795014	total: 374ms	remaining: 10.4s
# 347:	learn: 0.2790795	total: 375ms	remaining: 10.4s
# 348:	learn: 0.2787795	total: 376ms	remaining: 10.4s
# 349:	learn: 0.2785318	total: 377ms	remaining: 10.4s
# 350:	learn: 0.2781593	total: 378ms	remaining: 10.4s
# 351:	learn: 0.2776353	total: 379ms	remaining: 10.4s
# 352:	learn: 0.2773222	total: 380ms	remaining: 10.4s
# 353:	learn: 0.2769435	total: 381ms	remaining: 10.4s
# 354:	learn: 0.2766992	total: 382ms	remaining: 10.4s
# 355:	learn: 0.2762164	total: 383ms	remaining: 10.4s
# 356:	learn: 0.2759214	total: 384ms	remaining: 10.4s
# 357:	learn: 0.2756791	total: 385ms	remaining: 10.4s
# 358:	learn: 0.2753654	total: 386ms	remaining: 10.4s
# 359:	learn: 0.2751170	total: 387ms	remaining: 10.4s
# 360:	learn: 0.2748148	total: 388ms	remaining: 10.4s
# 361:	learn: 0.2745067	total: 389ms	remaining: 10.4s
# 362:	learn: 0.2742954	total: 390ms	remaining: 10.4s
# 363:	learn: 0.2739135	total: 392ms	remaining: 10.4s
# 364:	learn: 0.2735505	total: 393ms	remaining: 10.4s
# 365:	learn: 0.2732752	total: 394ms	remaining: 10.4s
# 366:	learn: 0.2728243	total: 395ms	remaining: 10.4s
# 367:	learn: 0.2724228	total: 396ms	remaining: 10.4s
# 368:	learn: 0.2722489	total: 397ms	remaining: 10.4s
# 369:	learn: 0.2720010	total: 398ms	remaining: 10.4s
# 370:	learn: 0.2716661	total: 399ms	remaining: 10.4s
# 371:	learn: 0.2713391	total: 400ms	remaining: 10.4s
# 372:	learn: 0.2709526	total: 402ms	remaining: 10.4s
# 373:	learn: 0.2706150	total: 403ms	remaining: 10.4s
# 374:	learn: 0.2702726	total: 404ms	remaining: 10.4s
# 375:	learn: 0.2700004	total: 405ms	remaining: 10.4s
# 376:	learn: 0.2697562	total: 406ms	remaining: 10.4s
# 377:	learn: 0.2694235	total: 407ms	remaining: 10.4s
# 378:	learn: 0.2689737	total: 408ms	remaining: 10.4s
# 379:	learn: 0.2686555	total: 409ms	remaining: 10.4s
# 380:	learn: 0.2683939	total: 410ms	remaining: 10.4s
# 381:	learn: 0.2678839	total: 411ms	remaining: 10.3s
# 382:	learn: 0.2674991	total: 412ms	remaining: 10.3s
# 383:	learn: 0.2671386	total: 413ms	remaining: 10.3s
# 384:	learn: 0.2668188	total: 414ms	remaining: 10.3s
# 385:	learn: 0.2665869	total: 415ms	remaining: 10.3s
# 386:	learn: 0.2662451	total: 416ms	remaining: 10.3s
# 387:	learn: 0.2659954	total: 417ms	remaining: 10.3s
# 388:	learn: 0.2656582	total: 418ms	remaining: 10.3s
# 389:	learn: 0.2653600	total: 419ms	remaining: 10.3s
# 390:	learn: 0.2650613	total: 421ms	remaining: 10.3s
# 391:	learn: 0.2647748	total: 422ms	remaining: 10.3s
# 392:	learn: 0.2644191	total: 423ms	remaining: 10.3s
# 393:	learn: 0.2640725	total: 424ms	remaining: 10.3s
# 394:	learn: 0.2637556	total: 425ms	remaining: 10.3s
# 395:	learn: 0.2634553	total: 426ms	remaining: 10.3s
# 396:	learn: 0.2630723	total: 427ms	remaining: 10.3s
# 397:	learn: 0.2627786	total: 428ms	remaining: 10.3s
# 398:	learn: 0.2623632	total: 429ms	remaining: 10.3s
# 399:	learn: 0.2621807	total: 430ms	remaining: 10.3s
# 400:	learn: 0.2619485	total: 431ms	remaining: 10.3s
# 401:	learn: 0.2616347	total: 432ms	remaining: 10.3s
# 402:	learn: 0.2613617	total: 433ms	remaining: 10.3s
# 403:	learn: 0.2610579	total: 434ms	remaining: 10.3s
# 404:	learn: 0.2608565	total: 435ms	remaining: 10.3s
# 405:	learn: 0.2605579	total: 436ms	remaining: 10.3s
# 406:	learn: 0.2603607	total: 437ms	remaining: 10.3s
# 407:	learn: 0.2600726	total: 438ms	remaining: 10.3s
# 408:	learn: 0.2598332	total: 439ms	remaining: 10.3s
# 409:	learn: 0.2595957	total: 440ms	remaining: 10.3s
# 410:	learn: 0.2593864	total: 441ms	remaining: 10.3s
# 411:	learn: 0.2590988	total: 442ms	remaining: 10.3s
# 412:	learn: 0.2588790	total: 443ms	remaining: 10.3s
# 413:	learn: 0.2585794	total: 444ms	remaining: 10.3s
# 414:	learn: 0.2582910	total: 446ms	remaining: 10.3s
# 415:	learn: 0.2580395	total: 447ms	remaining: 10.3s
# 416:	learn: 0.2578363	total: 448ms	remaining: 10.3s
# 417:	learn: 0.2575160	total: 449ms	remaining: 10.3s
# 418:	learn: 0.2571306	total: 450ms	remaining: 10.3s
# 419:	learn: 0.2568112	total: 452ms	remaining: 10.3s
# 420:	learn: 0.2565285	total: 453ms	remaining: 10.3s
# 421:	learn: 0.2562297	total: 454ms	remaining: 10.3s
# 422:	learn: 0.2558561	total: 455ms	remaining: 10.3s
# 423:	learn: 0.2554892	total: 456ms	remaining: 10.3s
# 424:	learn: 0.2551401	total: 457ms	remaining: 10.3s
# 425:	learn: 0.2548480	total: 458ms	remaining: 10.3s
# 426:	learn: 0.2544898	total: 459ms	remaining: 10.3s
# 427:	learn: 0.2542082	total: 460ms	remaining: 10.3s
# 428:	learn: 0.2539721	total: 461ms	remaining: 10.3s
# 429:	learn: 0.2537902	total: 462ms	remaining: 10.3s
# 430:	learn: 0.2535259	total: 464ms	remaining: 10.3s
# 431:	learn: 0.2533157	total: 465ms	remaining: 10.3s
# 432:	learn: 0.2530771	total: 466ms	remaining: 10.3s
# 433:	learn: 0.2527982	total: 467ms	remaining: 10.3s
# 434:	learn: 0.2525186	total: 468ms	remaining: 10.3s
# 435:	learn: 0.2522762	total: 469ms	remaining: 10.3s
# 436:	learn: 0.2520050	total: 470ms	remaining: 10.3s
# 437:	learn: 0.2517742	total: 471ms	remaining: 10.3s
# 438:	learn: 0.2515267	total: 472ms	remaining: 10.3s
# 439:	learn: 0.2512458	total: 473ms	remaining: 10.3s
# 440:	learn: 0.2510287	total: 474ms	remaining: 10.3s
# 441:	learn: 0.2508457	total: 475ms	remaining: 10.3s
# 442:	learn: 0.2505701	total: 476ms	remaining: 10.3s
# 443:	learn: 0.2503351	total: 477ms	remaining: 10.3s
# 444:	learn: 0.2500771	total: 478ms	remaining: 10.3s
# 445:	learn: 0.2499088	total: 479ms	remaining: 10.3s
# 446:	learn: 0.2496869	total: 480ms	remaining: 10.3s
# 447:	learn: 0.2494451	total: 481ms	remaining: 10.3s
# 448:	learn: 0.2491344	total: 482ms	remaining: 10.3s
# 449:	learn: 0.2488758	total: 483ms	remaining: 10.3s
# 450:	learn: 0.2485380	total: 485ms	remaining: 10.3s
# 451:	learn: 0.2482688	total: 486ms	remaining: 10.3s
# 452:	learn: 0.2479980	total: 487ms	remaining: 10.3s
# 453:	learn: 0.2477581	total: 488ms	remaining: 10.3s
# 454:	learn: 0.2475393	total: 489ms	remaining: 10.3s
# 455:	learn: 0.2472450	total: 490ms	remaining: 10.3s
# 456:	learn: 0.2469046	total: 491ms	remaining: 10.3s
# 457:	learn: 0.2467175	total: 492ms	remaining: 10.2s
# 458:	learn: 0.2465389	total: 493ms	remaining: 10.2s
# 459:	learn: 0.2462516	total: 494ms	remaining: 10.2s
# 460:	learn: 0.2461055	total: 495ms	remaining: 10.2s
# 461:	learn: 0.2458788	total: 496ms	remaining: 10.2s
# 462:	learn: 0.2457278	total: 497ms	remaining: 10.2s
# 463:	learn: 0.2454672	total: 498ms	remaining: 10.2s
# 464:	learn: 0.2451998	total: 499ms	remaining: 10.2s
# 465:	learn: 0.2450091	total: 500ms	remaining: 10.2s
# 466:	learn: 0.2447091	total: 501ms	remaining: 10.2s
# 467:	learn: 0.2444887	total: 502ms	remaining: 10.2s
# 468:	learn: 0.2443222	total: 503ms	remaining: 10.2s
# 469:	learn: 0.2440570	total: 504ms	remaining: 10.2s
# 470:	learn: 0.2438429	total: 505ms	remaining: 10.2s
# 471:	learn: 0.2436859	total: 506ms	remaining: 10.2s
# 472:	learn: 0.2435014	total: 508ms	remaining: 10.2s
# 473:	learn: 0.2432323	total: 514ms	remaining: 10.3s
# 474:	learn: 0.2429812	total: 515ms	remaining: 10.3s
# 475:	learn: 0.2427676	total: 516ms	remaining: 10.3s
# 476:	learn: 0.2424087	total: 517ms	remaining: 10.3s
# 477:	learn: 0.2421009	total: 518ms	remaining: 10.3s
# 478:	learn: 0.2417932	total: 519ms	remaining: 10.3s
# 479:	learn: 0.2416230	total: 521ms	remaining: 10.3s
# 480:	learn: 0.2413812	total: 522ms	remaining: 10.3s
# 481:	learn: 0.2411088	total: 523ms	remaining: 10.3s
# 482:	learn: 0.2407732	total: 524ms	remaining: 10.3s
# 483:	learn: 0.2405996	total: 525ms	remaining: 10.3s
# 484:	learn: 0.2402849	total: 526ms	remaining: 10.3s
# 485:	learn: 0.2400747	total: 527ms	remaining: 10.3s
# 486:	learn: 0.2398878	total: 528ms	remaining: 10.3s
# 487:	learn: 0.2396977	total: 529ms	remaining: 10.3s
# 488:	learn: 0.2394317	total: 530ms	remaining: 10.3s
# 489:	learn: 0.2392475	total: 531ms	remaining: 10.3s
# 490:	learn: 0.2388801	total: 532ms	remaining: 10.3s
# 491:	learn: 0.2385895	total: 533ms	remaining: 10.3s
# 492:	learn: 0.2383823	total: 534ms	remaining: 10.3s
# 493:	learn: 0.2381577	total: 535ms	remaining: 10.3s
# 494:	learn: 0.2379632	total: 536ms	remaining: 10.3s
# 495:	learn: 0.2378158	total: 537ms	remaining: 10.3s
# 496:	learn: 0.2375610	total: 538ms	remaining: 10.3s
# 497:	learn: 0.2373588	total: 539ms	remaining: 10.3s
# 498:	learn: 0.2371616	total: 541ms	remaining: 10.3s
# 499:	learn: 0.2369693	total: 542ms	remaining: 10.3s
# 500:	learn: 0.2367774	total: 543ms	remaining: 10.3s
# 501:	learn: 0.2366078	total: 544ms	remaining: 10.3s
# 502:	learn: 0.2363815	total: 545ms	remaining: 10.3s
# 503:	learn: 0.2361169	total: 546ms	remaining: 10.3s
# 504:	learn: 0.2359134	total: 547ms	remaining: 10.3s
# 505:	learn: 0.2357013	total: 548ms	remaining: 10.3s
# 506:	learn: 0.2354634	total: 553ms	remaining: 10.3s
# 507:	learn: 0.2352022	total: 554ms	remaining: 10.3s
# 508:	learn: 0.2349082	total: 555ms	remaining: 10.3s
# 509:	learn: 0.2346342	total: 556ms	remaining: 10.3s
# 510:	learn: 0.2344035	total: 557ms	remaining: 10.3s
# 511:	learn: 0.2341830	total: 558ms	remaining: 10.3s
# 512:	learn: 0.2340055	total: 559ms	remaining: 10.3s
# 513:	learn: 0.2338088	total: 560ms	remaining: 10.3s
# 514:	learn: 0.2335981	total: 561ms	remaining: 10.3s
# 515:	learn: 0.2334478	total: 562ms	remaining: 10.3s
# 516:	learn: 0.2332433	total: 563ms	remaining: 10.3s
# 517:	learn: 0.2330496	total: 564ms	remaining: 10.3s
# 518:	learn: 0.2328185	total: 565ms	remaining: 10.3s
# 519:	learn: 0.2325788	total: 566ms	remaining: 10.3s
# 520:	learn: 0.2323617	total: 567ms	remaining: 10.3s
# 521:	learn: 0.2321510	total: 568ms	remaining: 10.3s
# 522:	learn: 0.2319213	total: 570ms	remaining: 10.3s
# 523:	learn: 0.2317685	total: 571ms	remaining: 10.3s
# 524:	learn: 0.2315578	total: 572ms	remaining: 10.3s
# 525:	learn: 0.2312386	total: 573ms	remaining: 10.3s
# 526:	learn: 0.2310321	total: 574ms	remaining: 10.3s
# 527:	learn: 0.2307808	total: 575ms	remaining: 10.3s
# 528:	learn: 0.2305418	total: 576ms	remaining: 10.3s
# 529:	learn: 0.2302448	total: 577ms	remaining: 10.3s
# 530:	learn: 0.2300547	total: 578ms	remaining: 10.3s
# 531:	learn: 0.2297635	total: 579ms	remaining: 10.3s
# 532:	learn: 0.2295674	total: 580ms	remaining: 10.3s
# 533:	learn: 0.2294011	total: 581ms	remaining: 10.3s
# 534:	learn: 0.2291815	total: 582ms	remaining: 10.3s
# 535:	learn: 0.2289862	total: 583ms	remaining: 10.3s
# 536:	learn: 0.2288134	total: 584ms	remaining: 10.3s
# 537:	learn: 0.2286159	total: 585ms	remaining: 10.3s
# 538:	learn: 0.2284693	total: 586ms	remaining: 10.3s
# 539:	learn: 0.2282834	total: 587ms	remaining: 10.3s
# 540:	learn: 0.2280731	total: 589ms	remaining: 10.3s
# 541:	learn: 0.2279101	total: 590ms	remaining: 10.3s
# 542:	learn: 0.2277089	total: 591ms	remaining: 10.3s
# 543:	learn: 0.2274216	total: 592ms	remaining: 10.3s
# 544:	learn: 0.2272487	total: 593ms	remaining: 10.3s
# 545:	learn: 0.2270272	total: 595ms	remaining: 10.3s
# 546:	learn: 0.2268445	total: 596ms	remaining: 10.3s
# 547:	learn: 0.2266070	total: 598ms	remaining: 10.3s
# 548:	learn: 0.2262872	total: 599ms	remaining: 10.3s
# 549:	learn: 0.2260701	total: 600ms	remaining: 10.3s
# 550:	learn: 0.2259071	total: 601ms	remaining: 10.3s
# 551:	learn: 0.2257318	total: 602ms	remaining: 10.3s
# 552:	learn: 0.2255494	total: 603ms	remaining: 10.3s
# 553:	learn: 0.2253724	total: 604ms	remaining: 10.3s
# 554:	learn: 0.2252069	total: 605ms	remaining: 10.3s
# 555:	learn: 0.2250418	total: 606ms	remaining: 10.3s
# 556:	learn: 0.2247981	total: 608ms	remaining: 10.3s
# 557:	learn: 0.2245820	total: 609ms	remaining: 10.3s
# 558:	learn: 0.2244299	total: 610ms	remaining: 10.3s
# 559:	learn: 0.2242848	total: 611ms	remaining: 10.3s
# 560:	learn: 0.2240874	total: 612ms	remaining: 10.3s
# 561:	learn: 0.2239096	total: 613ms	remaining: 10.3s
# 562:	learn: 0.2237571	total: 614ms	remaining: 10.3s
# 563:	learn: 0.2235802	total: 615ms	remaining: 10.3s
# 564:	learn: 0.2233449	total: 616ms	remaining: 10.3s
# 565:	learn: 0.2231592	total: 617ms	remaining: 10.3s
# 566:	learn: 0.2229467	total: 618ms	remaining: 10.3s
# 567:	learn: 0.2228152	total: 619ms	remaining: 10.3s
# 568:	learn: 0.2226517	total: 620ms	remaining: 10.3s
# 569:	learn: 0.2224901	total: 621ms	remaining: 10.3s
# 570:	learn: 0.2223001	total: 622ms	remaining: 10.3s
# 571:	learn: 0.2221389	total: 623ms	remaining: 10.3s
# 572:	learn: 0.2219323	total: 624ms	remaining: 10.3s
# 573:	learn: 0.2217372	total: 625ms	remaining: 10.3s
# 574:	learn: 0.2215912	total: 626ms	remaining: 10.3s
# 575:	learn: 0.2214176	total: 627ms	remaining: 10.3s
# 576:	learn: 0.2211882	total: 628ms	remaining: 10.3s
# 577:	learn: 0.2210213	total: 629ms	remaining: 10.3s
# 578:	learn: 0.2208260	total: 631ms	remaining: 10.3s
# 579:	learn: 0.2206463	total: 632ms	remaining: 10.3s
# 580:	learn: 0.2204553	total: 633ms	remaining: 10.3s
# 581:	learn: 0.2202945	total: 634ms	remaining: 10.3s
# 582:	learn: 0.2201472	total: 635ms	remaining: 10.3s
# 583:	learn: 0.2198898	total: 636ms	remaining: 10.2s
# 584:	learn: 0.2196906	total: 637ms	remaining: 10.2s
# 585:	learn: 0.2195470	total: 638ms	remaining: 10.2s
# 586:	learn: 0.2194023	total: 639ms	remaining: 10.2s
# 587:	learn: 0.2192414	total: 640ms	remaining: 10.2s
# 588:	learn: 0.2191063	total: 641ms	remaining: 10.2s
# 589:	learn: 0.2189088	total: 642ms	remaining: 10.2s
# 590:	learn: 0.2187194	total: 643ms	remaining: 10.2s
# 591:	learn: 0.2185661	total: 644ms	remaining: 10.2s
# 592:	learn: 0.2184316	total: 645ms	remaining: 10.2s
# 593:	learn: 0.2182568	total: 646ms	remaining: 10.2s
# 594:	learn: 0.2180949	total: 647ms	remaining: 10.2s
# 595:	learn: 0.2179615	total: 649ms	remaining: 10.2s
# 596:	learn: 0.2177908	total: 650ms	remaining: 10.2s
# 597:	learn: 0.2176180	total: 651ms	remaining: 10.2s
# 598:	learn: 0.2173304	total: 652ms	remaining: 10.2s
# 599:	learn: 0.2171440	total: 653ms	remaining: 10.2s
# 600:	learn: 0.2168921	total: 654ms	remaining: 10.2s
# 601:	learn: 0.2167235	total: 655ms	remaining: 10.2s
# 602:	learn: 0.2165174	total: 656ms	remaining: 10.2s
# 603:	learn: 0.2163010	total: 657ms	remaining: 10.2s
# 604:	learn: 0.2161413	total: 658ms	remaining: 10.2s
# 605:	learn: 0.2159262	total: 659ms	remaining: 10.2s
# 606:	learn: 0.2157198	total: 660ms	remaining: 10.2s
# 607:	learn: 0.2155307	total: 661ms	remaining: 10.2s
# 608:	learn: 0.2153042	total: 662ms	remaining: 10.2s
# 609:	learn: 0.2150984	total: 664ms	remaining: 10.2s
# 610:	learn: 0.2149424	total: 665ms	remaining: 10.2s
# 611:	learn: 0.2147827	total: 666ms	remaining: 10.2s
# 612:	learn: 0.2146320	total: 667ms	remaining: 10.2s
# 613:	learn: 0.2144453	total: 668ms	remaining: 10.2s
# 614:	learn: 0.2142818	total: 669ms	remaining: 10.2s
# 615:	learn: 0.2141436	total: 670ms	remaining: 10.2s
# 616:	learn: 0.2139906	total: 671ms	remaining: 10.2s
# 617:	learn: 0.2137869	total: 672ms	remaining: 10.2s
# 618:	learn: 0.2136233	total: 673ms	remaining: 10.2s
# 619:	learn: 0.2134754	total: 674ms	remaining: 10.2s
# 620:	learn: 0.2132840	total: 675ms	remaining: 10.2s
# 621:	learn: 0.2130811	total: 676ms	remaining: 10.2s
# 622:	learn: 0.2128345	total: 677ms	remaining: 10.2s
# 623:	learn: 0.2125921	total: 678ms	remaining: 10.2s
# 624:	learn: 0.2124557	total: 679ms	remaining: 10.2s
# 625:	learn: 0.2123231	total: 681ms	remaining: 10.2s
# 626:	learn: 0.2121660	total: 682ms	remaining: 10.2s
# 627:	learn: 0.2120161	total: 683ms	remaining: 10.2s
# 628:	learn: 0.2118503	total: 684ms	remaining: 10.2s
# 629:	learn: 0.2116770	total: 685ms	remaining: 10.2s
# 630:	learn: 0.2115060	total: 686ms	remaining: 10.2s
# 631:	learn: 0.2112750	total: 687ms	remaining: 10.2s
# 632:	learn: 0.2110535	total: 688ms	remaining: 10.2s
# 633:	learn: 0.2108686	total: 689ms	remaining: 10.2s
# 634:	learn: 0.2107417	total: 690ms	remaining: 10.2s
# 635:	learn: 0.2105165	total: 691ms	remaining: 10.2s
# 636:	learn: 0.2102765	total: 692ms	remaining: 10.2s
# 637:	learn: 0.2101324	total: 694ms	remaining: 10.2s
# 638:	learn: 0.2099923	total: 695ms	remaining: 10.2s
# 639:	learn: 0.2098333	total: 696ms	remaining: 10.2s
# 640:	learn: 0.2096190	total: 697ms	remaining: 10.2s
# 641:	learn: 0.2094560	total: 698ms	remaining: 10.2s
# 642:	learn: 0.2093121	total: 699ms	remaining: 10.2s
# 643:	learn: 0.2090887	total: 700ms	remaining: 10.2s
# 644:	learn: 0.2089392	total: 701ms	remaining: 10.2s
# 645:	learn: 0.2087373	total: 702ms	remaining: 10.2s
# 646:	learn: 0.2086326	total: 703ms	remaining: 10.2s
# 647:	learn: 0.2084280	total: 704ms	remaining: 10.2s
# 648:	learn: 0.2082541	total: 706ms	remaining: 10.2s
# 649:	learn: 0.2080714	total: 707ms	remaining: 10.2s
# 650:	learn: 0.2079675	total: 708ms	remaining: 10.2s
# 651:	learn: 0.2078331	total: 709ms	remaining: 10.2s
# 652:	learn: 0.2077077	total: 710ms	remaining: 10.2s
# 653:	learn: 0.2075233	total: 711ms	remaining: 10.2s
# 654:	learn: 0.2074049	total: 712ms	remaining: 10.2s
# 655:	learn: 0.2072588	total: 713ms	remaining: 10.2s
# 656:	learn: 0.2070646	total: 714ms	remaining: 10.2s
# 657:	learn: 0.2069100	total: 715ms	remaining: 10.2s
# 658:	learn: 0.2067675	total: 717ms	remaining: 10.2s
# 659:	learn: 0.2066178	total: 718ms	remaining: 10.2s
# 660:	learn: 0.2064249	total: 719ms	remaining: 10.2s
# 661:	learn: 0.2062779	total: 720ms	remaining: 10.2s
# 662:	learn: 0.2061144	total: 721ms	remaining: 10.2s
# 663:	learn: 0.2059815	total: 722ms	remaining: 10.1s
# 664:	learn: 0.2058161	total: 723ms	remaining: 10.1s
# 665:	learn: 0.2056743	total: 724ms	remaining: 10.1s
# 666:	learn: 0.2054578	total: 725ms	remaining: 10.1s
# 667:	learn: 0.2052999	total: 726ms	remaining: 10.1s
# 668:	learn: 0.2050874	total: 727ms	remaining: 10.1s
# 669:	learn: 0.2049520	total: 728ms	remaining: 10.1s
# 670:	learn: 0.2047357	total: 729ms	remaining: 10.1s
# 671:	learn: 0.2046123	total: 730ms	remaining: 10.1s
# 672:	learn: 0.2044476	total: 731ms	remaining: 10.1s
# 673:	learn: 0.2043298	total: 733ms	remaining: 10.1s
# 674:	learn: 0.2041833	total: 734ms	remaining: 10.1s
# 675:	learn: 0.2039336	total: 735ms	remaining: 10.1s
# 676:	learn: 0.2037248	total: 736ms	remaining: 10.1s
# 677:	learn: 0.2035887	total: 737ms	remaining: 10.1s
# 678:	learn: 0.2034191	total: 738ms	remaining: 10.1s
# 679:	learn: 0.2032509	total: 739ms	remaining: 10.1s
# 680:	learn: 0.2031304	total: 740ms	remaining: 10.1s
# 681:	learn: 0.2030130	total: 741ms	remaining: 10.1s
# 682:	learn: 0.2029015	total: 742ms	remaining: 10.1s
# 683:	learn: 0.2027715	total: 744ms	remaining: 10.1s
# 684:	learn: 0.2026126	total: 745ms	remaining: 10.1s
# 685:	learn: 0.2024382	total: 746ms	remaining: 10.1s
# 686:	learn: 0.2022987	total: 747ms	remaining: 10.1s
# 687:	learn: 0.2021763	total: 748ms	remaining: 10.1s
# 688:	learn: 0.2020240	total: 750ms	remaining: 10.1s
# 689:	learn: 0.2019141	total: 751ms	remaining: 10.1s
# 690:	learn: 0.2017252	total: 752ms	remaining: 10.1s
# 691:	learn: 0.2014998	total: 753ms	remaining: 10.1s
# 692:	learn: 0.2013104	total: 754ms	remaining: 10.1s
# 693:	learn: 0.2011504	total: 755ms	remaining: 10.1s
# 694:	learn: 0.2009775	total: 756ms	remaining: 10.1s
# 695:	learn: 0.2007897	total: 757ms	remaining: 10.1s
# 696:	learn: 0.2005889	total: 758ms	remaining: 10.1s
# 697:	learn: 0.2004702	total: 759ms	remaining: 10.1s
# 698:	learn: 0.2003559	total: 760ms	remaining: 10.1s
# 699:	learn: 0.2001980	total: 761ms	remaining: 10.1s
# 700:	learn: 0.2000959	total: 762ms	remaining: 10.1s
# 701:	learn: 0.1999732	total: 763ms	remaining: 10.1s
# 702:	learn: 0.1998327	total: 764ms	remaining: 10.1s
# 703:	learn: 0.1996989	total: 766ms	remaining: 10.1s
# 704:	learn: 0.1995115	total: 767ms	remaining: 10.1s
# 705:	learn: 0.1994086	total: 768ms	remaining: 10.1s
# 706:	learn: 0.1991313	total: 769ms	remaining: 10.1s
# 707:	learn: 0.1989771	total: 770ms	remaining: 10.1s
# 708:	learn: 0.1987500	total: 771ms	remaining: 10.1s
# 709:	learn: 0.1985557	total: 772ms	remaining: 10.1s
# 710:	learn: 0.1984407	total: 773ms	remaining: 10.1s
# 711:	learn: 0.1982416	total: 774ms	remaining: 10.1s
# 712:	learn: 0.1981060	total: 775ms	remaining: 10.1s
# 713:	learn: 0.1979595	total: 776ms	remaining: 10.1s
# 714:	learn: 0.1977977	total: 777ms	remaining: 10.1s
# 715:	learn: 0.1976542	total: 778ms	remaining: 10.1s
# 716:	learn: 0.1974878	total: 779ms	remaining: 10.1s
# 717:	learn: 0.1973665	total: 780ms	remaining: 10.1s
# 718:	learn: 0.1971986	total: 781ms	remaining: 10.1s
# 719:	learn: 0.1970842	total: 782ms	remaining: 10.1s
# 720:	learn: 0.1968903	total: 784ms	remaining: 10.1s
# 721:	learn: 0.1967108	total: 785ms	remaining: 10.1s
# 722:	learn: 0.1965288	total: 786ms	remaining: 10.1s
# 723:	learn: 0.1964274	total: 787ms	remaining: 10.1s
# 724:	learn: 0.1962884	total: 788ms	remaining: 10.1s
# 725:	learn: 0.1961279	total: 790ms	remaining: 10.1s
# 726:	learn: 0.1960086	total: 791ms	remaining: 10.1s
# 727:	learn: 0.1958884	total: 792ms	remaining: 10.1s
# 728:	learn: 0.1957231	total: 793ms	remaining: 10.1s
# 729:	learn: 0.1955790	total: 794ms	remaining: 10.1s
# 730:	learn: 0.1954335	total: 795ms	remaining: 10.1s
# 731:	learn: 0.1953037	total: 796ms	remaining: 10.1s
# 732:	learn: 0.1951481	total: 797ms	remaining: 10.1s
# 733:	learn: 0.1949736	total: 798ms	remaining: 10.1s
# 734:	learn: 0.1948446	total: 799ms	remaining: 10.1s
# 735:	learn: 0.1947332	total: 800ms	remaining: 10.1s
# 736:	learn: 0.1945993	total: 801ms	remaining: 10.1s
# 737:	learn: 0.1944767	total: 802ms	remaining: 10.1s
# 738:	learn: 0.1942621	total: 803ms	remaining: 10.1s
# 739:	learn: 0.1941018	total: 804ms	remaining: 10.1s
# 740:	learn: 0.1940049	total: 805ms	remaining: 10.1s
# 741:	learn: 0.1938788	total: 806ms	remaining: 10.1s
# 742:	learn: 0.1937831	total: 807ms	remaining: 10.1s
# 743:	learn: 0.1936768	total: 808ms	remaining: 10.1s
# 744:	learn: 0.1935672	total: 809ms	remaining: 10.1s
# 745:	learn: 0.1934137	total: 810ms	remaining: 10s
# 746:	learn: 0.1933151	total: 811ms	remaining: 10s
# 747:	learn: 0.1931868	total: 812ms	remaining: 10s
# 748:	learn: 0.1930603	total: 814ms	remaining: 10s
# 749:	learn: 0.1929226	total: 815ms	remaining: 10s
# 750:	learn: 0.1927402	total: 816ms	remaining: 10s
# 751:	learn: 0.1925549	total: 817ms	remaining: 10s
# 752:	learn: 0.1924327	total: 818ms	remaining: 10s
# 753:	learn: 0.1923081	total: 819ms	remaining: 10s
# 754:	learn: 0.1921917	total: 820ms	remaining: 10s
# 755:	learn: 0.1920382	total: 821ms	remaining: 10s
# 756:	learn: 0.1919146	total: 822ms	remaining: 10s
# 757:	learn: 0.1917953	total: 823ms	remaining: 10s
# 758:	learn: 0.1916381	total: 824ms	remaining: 10s
# 759:	learn: 0.1914703	total: 825ms	remaining: 10s
# 760:	learn: 0.1913460	total: 826ms	remaining: 10s
# 761:	learn: 0.1911747	total: 827ms	remaining: 10s
# 762:	learn: 0.1910524	total: 828ms	remaining: 10s
# 763:	learn: 0.1908950	total: 829ms	remaining: 10s
# 764:	learn: 0.1907335	total: 830ms	remaining: 10s
# 765:	learn: 0.1905562	total: 831ms	remaining: 10s
# 766:	learn: 0.1904583	total: 834ms	remaining: 10s
# 767:	learn: 0.1903094	total: 835ms	remaining: 10s
# 768:	learn: 0.1902261	total: 836ms	remaining: 10s
# 769:	learn: 0.1900850	total: 838ms	remaining: 10s
# 770:	learn: 0.1899756	total: 839ms	remaining: 10s
# 771:	learn: 0.1897490	total: 840ms	remaining: 10s
# 772:	learn: 0.1896335	total: 841ms	remaining: 10s
# 773:	learn: 0.1894119	total: 842ms	remaining: 10s
# 774:	learn: 0.1892813	total: 843ms	remaining: 10s
# 775:	learn: 0.1891606	total: 844ms	remaining: 10s
# 776:	learn: 0.1890318	total: 845ms	remaining: 10s
# 777:	learn: 0.1888835	total: 846ms	remaining: 10s
# 778:	learn: 0.1888021	total: 847ms	remaining: 10s
# 779:	learn: 0.1886734	total: 848ms	remaining: 10s
# 780:	learn: 0.1885648	total: 849ms	remaining: 10s
# 781:	learn: 0.1884705	total: 850ms	remaining: 10s
# 782:	learn: 0.1883764	total: 851ms	remaining: 10s
# 783:	learn: 0.1882815	total: 853ms	remaining: 10s
# 784:	learn: 0.1881041	total: 854ms	remaining: 10s
# 785:	learn: 0.1879971	total: 855ms	remaining: 10s
# 786:	learn: 0.1878711	total: 856ms	remaining: 10s
# 787:	learn: 0.1877049	total: 857ms	remaining: 10s
# 788:	learn: 0.1875651	total: 858ms	remaining: 10s
# 789:	learn: 0.1874267	total: 859ms	remaining: 10s
# 790:	learn: 0.1872845	total: 860ms	remaining: 10s
# 791:	learn: 0.1871701	total: 861ms	remaining: 10s
# 792:	learn: 0.1870202	total: 862ms	remaining: 10s
# 793:	learn: 0.1868814	total: 863ms	remaining: 10s
# 794:	learn: 0.1866961	total: 864ms	remaining: 10s
# 795:	learn: 0.1865415	total: 865ms	remaining: 10s
# 796:	learn: 0.1864466	total: 866ms	remaining: 10s
# 797:	learn: 0.1862881	total: 868ms	remaining: 10s
# 798:	learn: 0.1861643	total: 869ms	remaining: 10s
# 799:	learn: 0.1860325	total: 870ms	remaining: 10s
# 800:	learn: 0.1858743	total: 871ms	remaining: 10s
# 801:	learn: 0.1857686	total: 872ms	remaining: 10s
# 802:	learn: 0.1856353	total: 873ms	remaining: 10s
# 803:	learn: 0.1855157	total: 874ms	remaining: 10s
# 804:	learn: 0.1853723	total: 875ms	remaining: 10s
# 805:	learn: 0.1852300	total: 876ms	remaining: 9.99s
# 806:	learn: 0.1850998	total: 877ms	remaining: 9.99s
# 807:	learn: 0.1849489	total: 878ms	remaining: 9.99s
# 808:	learn: 0.1848129	total: 879ms	remaining: 9.99s
# 809:	learn: 0.1846646	total: 880ms	remaining: 9.99s
# 810:	learn: 0.1844329	total: 882ms	remaining: 9.99s
# 811:	learn: 0.1843136	total: 883ms	remaining: 9.99s
# 812:	learn: 0.1842045	total: 884ms	remaining: 9.98s
# 813:	learn: 0.1840931	total: 885ms	remaining: 9.98s
# 814:	learn: 0.1839460	total: 886ms	remaining: 9.98s
# 815:	learn: 0.1837778	total: 887ms	remaining: 9.98s
# 816:	learn: 0.1836484	total: 888ms	remaining: 9.98s
# 817:	learn: 0.1834753	total: 889ms	remaining: 9.98s
# 818:	learn: 0.1833511	total: 890ms	remaining: 9.98s
# 819:	learn: 0.1832103	total: 891ms	remaining: 9.97s
# 820:	learn: 0.1831083	total: 892ms	remaining: 9.97s
# 821:	learn: 0.1829827	total: 893ms	remaining: 9.97s
# 822:	learn: 0.1828245	total: 894ms	remaining: 9.97s
# 823:	learn: 0.1827300	total: 895ms	remaining: 9.97s
# 824:	learn: 0.1825842	total: 896ms	remaining: 9.97s
# 825:	learn: 0.1824678	total: 897ms	remaining: 9.97s
# 826:	learn: 0.1823172	total: 898ms	remaining: 9.96s
# 827:	learn: 0.1822047	total: 899ms	remaining: 9.96s
# 828:	learn: 0.1820308	total: 901ms	remaining: 9.96s
# 829:	learn: 0.1818544	total: 902ms	remaining: 9.96s
# 830:	learn: 0.1817412	total: 903ms	remaining: 9.96s
# 831:	learn: 0.1815956	total: 904ms	remaining: 9.96s
# 832:	learn: 0.1814814	total: 905ms	remaining: 9.96s
# 833:	learn: 0.1813611	total: 906ms	remaining: 9.96s
# 834:	learn: 0.1811986	total: 907ms	remaining: 9.96s
# 835:	learn: 0.1810577	total: 908ms	remaining: 9.95s
# 836:	learn: 0.1809251	total: 909ms	remaining: 9.95s
# 837:	learn: 0.1807991	total: 910ms	remaining: 9.95s
# 838:	learn: 0.1806426	total: 911ms	remaining: 9.95s
# 839:	learn: 0.1805171	total: 912ms	remaining: 9.95s
# 840:	learn: 0.1803566	total: 913ms	remaining: 9.95s
# 841:	learn: 0.1802933	total: 914ms	remaining: 9.94s
# 842:	learn: 0.1801670	total: 915ms	remaining: 9.94s
# 843:	learn: 0.1800543	total: 916ms	remaining: 9.94s
# 844:	learn: 0.1799581	total: 917ms	remaining: 9.94s
# 845:	learn: 0.1798643	total: 919ms	remaining: 9.94s
# 846:	learn: 0.1797333	total: 920ms	remaining: 9.94s
# 847:	learn: 0.1796000	total: 921ms	remaining: 9.94s
# 848:	learn: 0.1794339	total: 922ms	remaining: 9.93s
# 849:	learn: 0.1793575	total: 923ms	remaining: 9.93s
# 850:	learn: 0.1792546	total: 924ms	remaining: 9.93s
# 851:	learn: 0.1791749	total: 925ms	remaining: 9.93s
# 852:	learn: 0.1790233	total: 926ms	remaining: 9.93s
# 853:	learn: 0.1789275	total: 927ms	remaining: 9.93s
# 854:	learn: 0.1788434	total: 928ms	remaining: 9.93s
# 855:	learn: 0.1786673	total: 929ms	remaining: 9.92s
# 856:	learn: 0.1785207	total: 930ms	remaining: 9.92s
# 857:	learn: 0.1784174	total: 931ms	remaining: 9.92s
# 858:	learn: 0.1783163	total: 932ms	remaining: 9.92s
# 859:	learn: 0.1781970	total: 933ms	remaining: 9.92s
# 860:	learn: 0.1780400	total: 934ms	remaining: 9.92s
# 861:	learn: 0.1779204	total: 935ms	remaining: 9.92s
# 862:	learn: 0.1777783	total: 936ms	remaining: 9.91s
# 863:	learn: 0.1775861	total: 938ms	remaining: 9.91s
# 864:	learn: 0.1774660	total: 939ms	remaining: 9.91s
# 865:	learn: 0.1773249	total: 940ms	remaining: 9.91s
# 866:	learn: 0.1772346	total: 941ms	remaining: 9.91s
# 867:	learn: 0.1770908	total: 942ms	remaining: 9.91s
# 868:	learn: 0.1769626	total: 943ms	remaining: 9.91s
# 869:	learn: 0.1768395	total: 944ms	remaining: 9.91s
# 870:	learn: 0.1767469	total: 945ms	remaining: 9.9s
# 871:	learn: 0.1765916	total: 946ms	remaining: 9.9s
# 872:	learn: 0.1764407	total: 947ms	remaining: 9.9s
# 873:	learn: 0.1763311	total: 948ms	remaining: 9.9s
# 874:	learn: 0.1762139	total: 949ms	remaining: 9.9s
# 875:	learn: 0.1760586	total: 950ms	remaining: 9.9s
# 876:	learn: 0.1759633	total: 951ms	remaining: 9.9s
# 877:	learn: 0.1757981	total: 953ms	remaining: 9.9s
# 878:	learn: 0.1756675	total: 954ms	remaining: 9.89s
# 879:	learn: 0.1755852	total: 955ms	remaining: 9.89s
# 880:	learn: 0.1754958	total: 956ms	remaining: 9.89s
# 881:	learn: 0.1754388	total: 957ms	remaining: 9.89s
# 882:	learn: 0.1753328	total: 958ms	remaining: 9.89s
# 883:	learn: 0.1752526	total: 959ms	remaining: 9.89s
# 884:	learn: 0.1751319	total: 960ms	remaining: 9.89s
# 885:	learn: 0.1750218	total: 961ms	remaining: 9.88s
# 886:	learn: 0.1749380	total: 962ms	remaining: 9.88s
# 887:	learn: 0.1748397	total: 963ms	remaining: 9.88s
# 888:	learn: 0.1747143	total: 964ms	remaining: 9.88s
# 889:	learn: 0.1745858	total: 965ms	remaining: 9.88s
# 890:	learn: 0.1744795	total: 966ms	remaining: 9.88s
# 891:	learn: 0.1743109	total: 967ms	remaining: 9.88s
# 892:	learn: 0.1741886	total: 968ms	remaining: 9.88s
# 893:	learn: 0.1740763	total: 969ms	remaining: 9.87s
# 894:	learn: 0.1739827	total: 970ms	remaining: 9.87s
# 895:	learn: 0.1738608	total: 971ms	remaining: 9.87s
# 896:	learn: 0.1737317	total: 973ms	remaining: 9.87s
# 897:	learn: 0.1736563	total: 974ms	remaining: 9.87s
# 898:	learn: 0.1735859	total: 975ms	remaining: 9.87s
# 899:	learn: 0.1734426	total: 976ms	remaining: 9.86s
# 900:	learn: 0.1732921	total: 977ms	remaining: 9.86s
# 901:	learn: 0.1731371	total: 978ms	remaining: 9.86s
# 902:	learn: 0.1730337	total: 979ms	remaining: 9.86s
# 903:	learn: 0.1728903	total: 980ms	remaining: 9.86s
# 904:	learn: 0.1727709	total: 981ms	remaining: 9.86s
# 905:	learn: 0.1726615	total: 982ms	remaining: 9.86s
# 906:	learn: 0.1725670	total: 983ms	remaining: 9.86s
# 907:	learn: 0.1724498	total: 984ms	remaining: 9.86s
# 908:	learn: 0.1722955	total: 985ms	remaining: 9.85s
# 909:	learn: 0.1721966	total: 986ms	remaining: 9.85s
# 910:	learn: 0.1720798	total: 987ms	remaining: 9.85s
# 911:	learn: 0.1719384	total: 988ms	remaining: 9.85s
# 912:	learn: 0.1718437	total: 990ms	remaining: 9.85s
# 913:	learn: 0.1717114	total: 991ms	remaining: 9.85s
# 914:	learn: 0.1715065	total: 992ms	remaining: 9.85s
# 915:	learn: 0.1714414	total: 993ms	remaining: 9.84s
# 916:	learn: 0.1713492	total: 994ms	remaining: 9.84s
# 917:	learn: 0.1712206	total: 995ms	remaining: 9.84s
# 918:	learn: 0.1711338	total: 996ms	remaining: 9.84s
# 919:	learn: 0.1710308	total: 997ms	remaining: 9.84s
# 920:	learn: 0.1708987	total: 998ms	remaining: 9.84s
# 921:	learn: 0.1708061	total: 999ms	remaining: 9.83s
# 922:	learn: 0.1706600	total: 1000ms	remaining: 9.83s
# 923:	learn: 0.1705568	total: 1s	remaining: 9.83s
# 924:	learn: 0.1704422	total: 1s	remaining: 9.83s
# 925:	learn: 0.1703251	total: 1s	remaining: 9.83s
# ...
# 9700:	learn: 0.0083953	total: 10.4s	remaining: 321ms
# 9701:	learn: 0.0083941	total: 10.4s	remaining: 319ms
# 9702:	learn: 0.0083914	total: 10.4s	remaining: 318ms
# 9703:	learn: 0.0083900	total: 10.4s	remaining: 317ms
# 9704:	learn: 0.0083885	total: 10.4s	remaining: 316ms
# 9705:	learn: 0.0083885	total: 10.4s	remaining: 315ms
# 9706:	learn: 0.0083869	total: 10.4s	remaining: 314ms
# 9707:	learn: 0.0083858	total: 10.4s	remaining: 313ms
# 9708:	learn: 0.0083841	total: 10.4s	remaining: 312ms
# 9709:	learn: 0.0083826	total: 10.4s	remaining: 311ms
# 9710:	learn: 0.0083814	total: 10.4s	remaining: 310ms
# 9711:	learn: 0.0083803	total: 10.4s	remaining: 309ms
# 9712:	learn: 0.0083779	total: 10.4s	remaining: 308ms
# 9713:	learn: 0.0083762	total: 10.4s	remaining: 307ms
# 9714:	learn: 0.0083738	total: 10.4s	remaining: 306ms
# 9715:	learn: 0.0083716	total: 10.4s	remaining: 304ms
# 9716:	learn: 0.0083700	total: 10.4s	remaining: 303ms
# 9717:	learn: 0.0083678	total: 10.4s	remaining: 302ms
# 9718:	learn: 0.0083663	total: 10.4s	remaining: 301ms
# 9719:	learn: 0.0083646	total: 10.4s	remaining: 300ms
# 9720:	learn: 0.0083631	total: 10.4s	remaining: 299ms
# 9721:	learn: 0.0083608	total: 10.4s	remaining: 298ms
# 9722:	learn: 0.0083591	total: 10.4s	remaining: 297ms
# 9723:	learn: 0.0083575	total: 10.4s	remaining: 296ms
# 9724:	learn: 0.0083561	total: 10.4s	remaining: 295ms
# 9725:	learn: 0.0083541	total: 10.4s	remaining: 294ms
# 9726:	learn: 0.0083527	total: 10.4s	remaining: 293ms
# 9727:	learn: 0.0083526	total: 10.4s	remaining: 292ms
# 9728:	learn: 0.0083506	total: 10.4s	remaining: 291ms
# 9729:	learn: 0.0083492	total: 10.4s	remaining: 289ms
# 9730:	learn: 0.0083474	total: 10.4s	remaining: 288ms
# 9731:	learn: 0.0083475	total: 10.4s	remaining: 287ms
# 9732:	learn: 0.0083458	total: 10.4s	remaining: 286ms
# 9733:	learn: 0.0083447	total: 10.4s	remaining: 285ms
# 9734:	learn: 0.0083425	total: 10.4s	remaining: 284ms
# 9735:	learn: 0.0083413	total: 10.4s	remaining: 283ms
# 9736:	learn: 0.0083395	total: 10.4s	remaining: 282ms
# 9737:	learn: 0.0083384	total: 10.4s	remaining: 281ms
# 9738:	learn: 0.0083384	total: 10.4s	remaining: 280ms
# 9739:	learn: 0.0083368	total: 10.4s	remaining: 279ms
# 9740:	learn: 0.0083345	total: 10.4s	remaining: 278ms
# 9741:	learn: 0.0083325	total: 10.4s	remaining: 277ms
# 9742:	learn: 0.0083301	total: 10.4s	remaining: 276ms
# 9743:	learn: 0.0083289	total: 10.4s	remaining: 274ms
# 9744:	learn: 0.0083274	total: 10.4s	remaining: 273ms
# 9745:	learn: 0.0083259	total: 10.4s	remaining: 272ms
# 9746:	learn: 0.0083259	total: 10.4s	remaining: 271ms
# 9747:	learn: 0.0083259	total: 10.5s	remaining: 270ms
# 9748:	learn: 0.0083242	total: 10.5s	remaining: 269ms
# 9749:	learn: 0.0083225	total: 10.5s	remaining: 268ms
# 9750:	learn: 0.0083199	total: 10.5s	remaining: 267ms
# 9751:	learn: 0.0083184	total: 10.5s	remaining: 266ms
# 9752:	learn: 0.0083178	total: 10.5s	remaining: 265ms
# 9753:	learn: 0.0083164	total: 10.5s	remaining: 264ms
# 9754:	learn: 0.0083146	total: 10.5s	remaining: 263ms
# 9755:	learn: 0.0083133	total: 10.5s	remaining: 262ms
# 9756:	learn: 0.0083108	total: 10.5s	remaining: 261ms
# 9757:	learn: 0.0083103	total: 10.5s	remaining: 259ms
# 9758:	learn: 0.0083084	total: 10.5s	remaining: 258ms
# 9759:	learn: 0.0083064	total: 10.5s	remaining: 257ms
# 9760:	learn: 0.0083047	total: 10.5s	remaining: 256ms
# 9761:	learn: 0.0083035	total: 10.5s	remaining: 255ms
# 9762:	learn: 0.0083015	total: 10.5s	remaining: 254ms
# 9763:	learn: 0.0083003	total: 10.5s	remaining: 253ms
# 9764:	learn: 0.0082988	total: 10.5s	remaining: 252ms
# 9765:	learn: 0.0082988	total: 10.5s	remaining: 251ms
# 9766:	learn: 0.0082982	total: 10.5s	remaining: 250ms
# 9767:	learn: 0.0082966	total: 10.5s	remaining: 249ms
# 9768:	learn: 0.0082962	total: 10.5s	remaining: 248ms
# 9769:	learn: 0.0082944	total: 10.5s	remaining: 247ms
# 9770:	learn: 0.0082933	total: 10.5s	remaining: 246ms
# 9771:	learn: 0.0082913	total: 10.5s	remaining: 244ms
# 9772:	learn: 0.0082896	total: 10.5s	remaining: 243ms
# 9773:	learn: 0.0082874	total: 10.5s	remaining: 242ms
# 9774:	learn: 0.0082857	total: 10.5s	remaining: 241ms
# 9775:	learn: 0.0082856	total: 10.5s	remaining: 240ms
# 9776:	learn: 0.0082857	total: 10.5s	remaining: 239ms
# 9777:	learn: 0.0082836	total: 10.5s	remaining: 238ms
# 9778:	learn: 0.0082820	total: 10.5s	remaining: 237ms
# 9779:	learn: 0.0082806	total: 10.5s	remaining: 236ms
# 9780:	learn: 0.0082791	total: 10.5s	remaining: 235ms
# 9781:	learn: 0.0082784	total: 10.5s	remaining: 234ms
# 9782:	learn: 0.0082767	total: 10.5s	remaining: 233ms
# 9783:	learn: 0.0082767	total: 10.5s	remaining: 232ms
# 9784:	learn: 0.0082750	total: 10.5s	remaining: 230ms
# 9785:	learn: 0.0082733	total: 10.5s	remaining: 229ms
# 9786:	learn: 0.0082716	total: 10.5s	remaining: 228ms
# 9787:	learn: 0.0082697	total: 10.5s	remaining: 227ms
# 9788:	learn: 0.0082679	total: 10.5s	remaining: 226ms
# 9789:	learn: 0.0082667	total: 10.5s	remaining: 225ms
# 9790:	learn: 0.0082646	total: 10.5s	remaining: 224ms
# 9791:	learn: 0.0082634	total: 10.5s	remaining: 223ms
# 9792:	learn: 0.0082634	total: 10.5s	remaining: 222ms
# 9793:	learn: 0.0082625	total: 10.5s	remaining: 221ms
# 9794:	learn: 0.0082610	total: 10.5s	remaining: 220ms
# 9795:	learn: 0.0082588	total: 10.5s	remaining: 219ms
# 9796:	learn: 0.0082553	total: 10.5s	remaining: 218ms
# 9797:	learn: 0.0082553	total: 10.5s	remaining: 217ms
# 9798:	learn: 0.0082553	total: 10.5s	remaining: 215ms
# 9799:	learn: 0.0082535	total: 10.5s	remaining: 214ms
# 9800:	learn: 0.0082535	total: 10.5s	remaining: 213ms
# 9801:	learn: 0.0082523	total: 10.5s	remaining: 212ms
# 9802:	learn: 0.0082523	total: 10.5s	remaining: 211ms
# 9803:	learn: 0.0082504	total: 10.5s	remaining: 210ms
# 9804:	learn: 0.0082486	total: 10.5s	remaining: 209ms
# 9805:	learn: 0.0082474	total: 10.5s	remaining: 208ms
# 9806:	learn: 0.0082456	total: 10.5s	remaining: 207ms
# 9807:	learn: 0.0082427	total: 10.5s	remaining: 206ms
# 9808:	learn: 0.0082412	total: 10.5s	remaining: 205ms
# 9809:	learn: 0.0082396	total: 10.5s	remaining: 204ms
# 9810:	learn: 0.0082369	total: 10.5s	remaining: 203ms
# 9811:	learn: 0.0082360	total: 10.5s	remaining: 202ms
# 9812:	learn: 0.0082359	total: 10.5s	remaining: 200ms
# 9813:	learn: 0.0082349	total: 10.5s	remaining: 199ms
# 9814:	learn: 0.0082333	total: 10.5s	remaining: 198ms
# 9815:	learn: 0.0082322	total: 10.5s	remaining: 197ms
# 9816:	learn: 0.0082315	total: 10.5s	remaining: 196ms
# 9817:	learn: 0.0082301	total: 10.5s	remaining: 195ms
# 9818:	learn: 0.0082282	total: 10.5s	remaining: 194ms
# 9819:	learn: 0.0082268	total: 10.5s	remaining: 193ms
# 9820:	learn: 0.0082251	total: 10.5s	remaining: 192ms
# 9821:	learn: 0.0082251	total: 10.5s	remaining: 191ms
# 9822:	learn: 0.0082233	total: 10.5s	remaining: 190ms
# 9823:	learn: 0.0082224	total: 10.5s	remaining: 189ms
# 9824:	learn: 0.0082224	total: 10.5s	remaining: 188ms
# 9825:	learn: 0.0082210	total: 10.5s	remaining: 187ms
# 9826:	learn: 0.0082197	total: 10.5s	remaining: 185ms
# 9827:	learn: 0.0082184	total: 10.5s	remaining: 184ms
# 9828:	learn: 0.0082174	total: 10.5s	remaining: 183ms
# 9829:	learn: 0.0082169	total: 10.5s	remaining: 182ms
# 9830:	learn: 0.0082152	total: 10.5s	remaining: 181ms
# 9831:	learn: 0.0082138	total: 10.5s	remaining: 180ms
# 9832:	learn: 0.0082122	total: 10.5s	remaining: 179ms
# 9833:	learn: 0.0082093	total: 10.5s	remaining: 178ms
# 9834:	learn: 0.0082093	total: 10.5s	remaining: 177ms
# 9835:	learn: 0.0082069	total: 10.5s	remaining: 176ms
# 9836:	learn: 0.0082058	total: 10.5s	remaining: 175ms
# 9837:	learn: 0.0082040	total: 10.5s	remaining: 174ms
# 9838:	learn: 0.0082022	total: 10.5s	remaining: 173ms
# 9839:	learn: 0.0081997	total: 10.5s	remaining: 172ms
# 9840:	learn: 0.0081980	total: 10.5s	remaining: 170ms
# 9841:	learn: 0.0081970	total: 10.6s	remaining: 169ms
# 9842:	learn: 0.0081960	total: 10.6s	remaining: 168ms
# 9843:	learn: 0.0081954	total: 10.6s	remaining: 167ms
# 9844:	learn: 0.0081931	total: 10.6s	remaining: 166ms
# 9845:	learn: 0.0081919	total: 10.6s	remaining: 165ms
# 9846:	learn: 0.0081901	total: 10.6s	remaining: 164ms
# 9847:	learn: 0.0081888	total: 10.6s	remaining: 163ms
# 9848:	learn: 0.0081876	total: 10.6s	remaining: 162ms
# 9849:	learn: 0.0081876	total: 10.6s	remaining: 161ms
# 9850:	learn: 0.0081876	total: 10.6s	remaining: 160ms
# 9851:	learn: 0.0081875	total: 10.6s	remaining: 159ms
# 9852:	learn: 0.0081863	total: 10.6s	remaining: 158ms
# 9853:	learn: 0.0081842	total: 10.6s	remaining: 156ms
# 9854:	learn: 0.0081833	total: 10.6s	remaining: 155ms
# 9855:	learn: 0.0081820	total: 10.6s	remaining: 154ms
# 9856:	learn: 0.0081820	total: 10.6s	remaining: 153ms
# 9857:	learn: 0.0081784	total: 10.6s	remaining: 152ms
# 9858:	learn: 0.0081784	total: 10.6s	remaining: 151ms
# 9859:	learn: 0.0081768	total: 10.6s	remaining: 150ms
# 9860:	learn: 0.0081754	total: 10.6s	remaining: 149ms
# 9861:	learn: 0.0081740	total: 10.6s	remaining: 148ms
# 9862:	learn: 0.0081723	total: 10.6s	remaining: 147ms
# 9863:	learn: 0.0081709	total: 10.6s	remaining: 146ms
# 9864:	learn: 0.0081698	total: 10.6s	remaining: 145ms
# 9865:	learn: 0.0081682	total: 10.6s	remaining: 144ms
# 9866:	learn: 0.0081671	total: 10.6s	remaining: 143ms
# 9867:	learn: 0.0081654	total: 10.6s	remaining: 141ms
# 9868:	learn: 0.0081638	total: 10.6s	remaining: 140ms
# 9869:	learn: 0.0081614	total: 10.6s	remaining: 139ms
# 9870:	learn: 0.0081595	total: 10.6s	remaining: 138ms
# 9871:	learn: 0.0081573	total: 10.6s	remaining: 137ms
# 9872:	learn: 0.0081559	total: 10.6s	remaining: 136ms
# 9873:	learn: 0.0081545	total: 10.6s	remaining: 135ms
# 9874:	learn: 0.0081545	total: 10.6s	remaining: 134ms
# 9875:	learn: 0.0081545	total: 10.6s	remaining: 133ms
# 9876:	learn: 0.0081531	total: 10.6s	remaining: 132ms
# 9877:	learn: 0.0081506	total: 10.6s	remaining: 131ms
# 9878:	learn: 0.0081494	total: 10.6s	remaining: 130ms
# 9879:	learn: 0.0081476	total: 10.6s	remaining: 129ms
# 9880:	learn: 0.0081454	total: 10.6s	remaining: 128ms
# 9881:	learn: 0.0081454	total: 10.6s	remaining: 126ms
# 9882:	learn: 0.0081440	total: 10.6s	remaining: 125ms
# 9883:	learn: 0.0081440	total: 10.6s	remaining: 124ms
# 9884:	learn: 0.0081427	total: 10.6s	remaining: 123ms
# 9885:	learn: 0.0081419	total: 10.6s	remaining: 122ms
# 9886:	learn: 0.0081406	total: 10.6s	remaining: 121ms
# 9887:	learn: 0.0081394	total: 10.6s	remaining: 120ms
# 9888:	learn: 0.0081385	total: 10.6s	remaining: 119ms
# 9889:	learn: 0.0081379	total: 10.6s	remaining: 118ms
# 9890:	learn: 0.0081359	total: 10.6s	remaining: 117ms
# 9891:	learn: 0.0081340	total: 10.6s	remaining: 116ms
# 9892:	learn: 0.0081311	total: 10.6s	remaining: 115ms
# 9893:	learn: 0.0081294	total: 10.6s	remaining: 114ms
# 9894:	learn: 0.0081276	total: 10.6s	remaining: 113ms
# 9895:	learn: 0.0081257	total: 10.6s	remaining: 111ms
# 9896:	learn: 0.0081241	total: 10.6s	remaining: 110ms
# 9897:	learn: 0.0081230	total: 10.6s	remaining: 109ms
# 9898:	learn: 0.0081214	total: 10.6s	remaining: 108ms
# 9899:	learn: 0.0081202	total: 10.6s	remaining: 107ms
# 9900:	learn: 0.0081188	total: 10.6s	remaining: 106ms
# 9901:	learn: 0.0081172	total: 10.6s	remaining: 105ms
# 9902:	learn: 0.0081156	total: 10.6s	remaining: 104ms
# 9903:	learn: 0.0081141	total: 10.6s	remaining: 103ms
# 9904:	learn: 0.0081129	total: 10.6s	remaining: 102ms
# 9905:	learn: 0.0081116	total: 10.6s	remaining: 101ms
# 9906:	learn: 0.0081106	total: 10.6s	remaining: 99.7ms
# 9907:	learn: 0.0081089	total: 10.6s	remaining: 98.6ms
# 9908:	learn: 0.0081083	total: 10.6s	remaining: 97.5ms
# 9909:	learn: 0.0081062	total: 10.6s	remaining: 96.5ms
# 9910:	learn: 0.0081046	total: 10.6s	remaining: 95.4ms
# 9911:	learn: 0.0081026	total: 10.6s	remaining: 94.3ms
# 9912:	learn: 0.0081009	total: 10.6s	remaining: 93.3ms
# 9913:	learn: 0.0080996	total: 10.6s	remaining: 92.2ms
# 9914:	learn: 0.0080976	total: 10.6s	remaining: 91.1ms
# 9915:	learn: 0.0080954	total: 10.6s	remaining: 90ms
# 9916:	learn: 0.0080945	total: 10.6s	remaining: 89ms
# 9917:	learn: 0.0080944	total: 10.6s	remaining: 87.9ms
# 9918:	learn: 0.0080930	total: 10.6s	remaining: 86.8ms
# 9919:	learn: 0.0080927	total: 10.6s	remaining: 85.8ms
# 9920:	learn: 0.0080927	total: 10.6s	remaining: 84.7ms
# 9921:	learn: 0.0080916	total: 10.6s	remaining: 83.6ms
# 9922:	learn: 0.0080901	total: 10.6s	remaining: 82.5ms
# 9923:	learn: 0.0080901	total: 10.6s	remaining: 81.5ms
# 9924:	learn: 0.0080901	total: 10.6s	remaining: 80.4ms
# 9925:	learn: 0.0080901	total: 10.6s	remaining: 79.3ms
# 9926:	learn: 0.0080890	total: 10.6s	remaining: 78.2ms
# 9927:	learn: 0.0080889	total: 10.6s	remaining: 77.2ms
# 9928:	learn: 0.0080847	total: 10.6s	remaining: 76.1ms
# 9929:	learn: 0.0080837	total: 10.6s	remaining: 75ms
# 9930:	learn: 0.0080824	total: 10.6s	remaining: 74ms
# 9931:	learn: 0.0080811	total: 10.6s	remaining: 72.9ms
# 9932:	learn: 0.0080796	total: 10.6s	remaining: 71.8ms
# 9933:	learn: 0.0080777	total: 10.6s	remaining: 70.7ms
# 9934:	learn: 0.0080763	total: 10.6s	remaining: 69.7ms
# 9935:	learn: 0.0080750	total: 10.6s	remaining: 68.6ms
# 9936:	learn: 0.0080751	total: 10.7s	remaining: 67.5ms
# 9937:	learn: 0.0080750	total: 10.7s	remaining: 66.5ms
# 9938:	learn: 0.0080739	total: 10.7s	remaining: 65.4ms
# 9939:	learn: 0.0080719	total: 10.7s	remaining: 64.3ms
# 9940:	learn: 0.0080711	total: 10.7s	remaining: 63.2ms
# 9941:	learn: 0.0080695	total: 10.7s	remaining: 62.2ms
# 9942:	learn: 0.0080694	total: 10.7s	remaining: 61.1ms
# 9943:	learn: 0.0080683	total: 10.7s	remaining: 60ms
# 9944:	learn: 0.0080666	total: 10.7s	remaining: 58.9ms
# 9945:	learn: 0.0080666	total: 10.7s	remaining: 57.9ms
# 9946:	learn: 0.0080653	total: 10.7s	remaining: 56.8ms
# 9947:	learn: 0.0080643	total: 10.7s	remaining: 55.7ms
# 9948:	learn: 0.0080629	total: 10.7s	remaining: 54.7ms
# 9949:	learn: 0.0080618	total: 10.7s	remaining: 53.6ms
# 9950:	learn: 0.0080603	total: 10.7s	remaining: 52.5ms
# 9951:	learn: 0.0080590	total: 10.7s	remaining: 51.5ms
# 9952:	learn: 0.0080574	total: 10.7s	remaining: 50.4ms
# 9953:	learn: 0.0080574	total: 10.7s	remaining: 49.3ms
# 9954:	learn: 0.0080560	total: 10.7s	remaining: 48.2ms
# 9955:	learn: 0.0080544	total: 10.7s	remaining: 47.2ms
# 9956:	learn: 0.0080529	total: 10.7s	remaining: 46.1ms
# 9957:	learn: 0.0080501	total: 10.7s	remaining: 45ms
# 9958:	learn: 0.0080497	total: 10.7s	remaining: 43.9ms
# 9959:	learn: 0.0080486	total: 10.7s	remaining: 42.9ms
# 9960:	learn: 0.0080476	total: 10.7s	remaining: 41.8ms
# 9961:	learn: 0.0080463	total: 10.7s	remaining: 40.7ms
# 9962:	learn: 0.0080446	total: 10.7s	remaining: 39.7ms
# 9963:	learn: 0.0080438	total: 10.7s	remaining: 38.6ms
# 9964:	learn: 0.0080429	total: 10.7s	remaining: 37.5ms
# 9965:	learn: 0.0080396	total: 10.7s	remaining: 36.4ms
# 9966:	learn: 0.0080396	total: 10.7s	remaining: 35.4ms
# 9967:	learn: 0.0080389	total: 10.7s	remaining: 34.3ms
# 9968:	learn: 0.0080378	total: 10.7s	remaining: 33.2ms
# 9969:	learn: 0.0080365	total: 10.7s	remaining: 32.2ms
# 9970:	learn: 0.0080352	total: 10.7s	remaining: 31.1ms
# 9971:	learn: 0.0080352	total: 10.7s	remaining: 30ms
# 9972:	learn: 0.0080340	total: 10.7s	remaining: 28.9ms
# 9973:	learn: 0.0080326	total: 10.7s	remaining: 27.9ms
# 9974:	learn: 0.0080313	total: 10.7s	remaining: 26.8ms
# 9975:	learn: 0.0080302	total: 10.7s	remaining: 25.7ms
# 9976:	learn: 0.0080286	total: 10.7s	remaining: 24.7ms
# 9977:	learn: 0.0080268	total: 10.7s	remaining: 23.6ms
# 9978:	learn: 0.0080256	total: 10.7s	remaining: 22.5ms
# 9979:	learn: 0.0080234	total: 10.7s	remaining: 21.4ms
# 9980:	learn: 0.0080223	total: 10.7s	remaining: 20.4ms
# 9981:	learn: 0.0080212	total: 10.7s	remaining: 19.3ms
# 9982:	learn: 0.0080195	total: 10.7s	remaining: 18.2ms
# 9983:	learn: 0.0080195	total: 10.7s	remaining: 17.1ms
# 9984:	learn: 0.0080183	total: 10.7s	remaining: 16.1ms
# 9985:	learn: 0.0080180	total: 10.7s	remaining: 15ms
# 9986:	learn: 0.0080180	total: 10.7s	remaining: 13.9ms
# 9987:	learn: 0.0080164	total: 10.7s	remaining: 12.9ms
# 9988:	learn: 0.0080150	total: 10.7s	remaining: 11.8ms
# 9989:	learn: 0.0080133	total: 10.7s	remaining: 10.7ms
# 9990:	learn: 0.0080125	total: 10.7s	remaining: 9.65ms
# 9991:	learn: 0.0080112	total: 10.7s	remaining: 8.57ms
# 9992:	learn: 0.0080098	total: 10.7s	remaining: 7.5ms
# 9993:	learn: 0.0080088	total: 10.7s	remaining: 6.43ms
# 9994:	learn: 0.0080073	total: 10.7s	remaining: 5.36ms
# 9995:	learn: 0.0080073	total: 10.7s	remaining: 4.29ms
# 9996:	learn: 0.0080073	total: 10.7s	remaining: 3.21ms
# 9997:	learn: 0.0080073	total: 10.7s	remaining: 2.14ms
# 9998:	learn: 0.0080062	total: 10.7s	remaining: 1.07ms
# 9999:	learn: 0.0080062	total: 10.7s	remaining: 0us

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    392292
#            1       0.97      0.79      0.87     54246
#
#     accuracy                           0.97    446538
#    macro avg       0.97      0.90      0.93    446538
# weighted avg       0.97      0.97      0.97    446538

# %%
3000 / (len(X_test) + len(X_train))
# Out:
# 0.006673547835990889

# %%
class Augmentor():

    def __init__(self, cfg):
        super(Augmentor, self).__init__()

        self.masking_ratio = cfg.masking_ratio
        self.mean_mask_length = cfg.mean_mask_length

        self.weak_jitter_sigma = cfg.weak_jitter_sigma
        self.weak_scaling_loc = cfg.weak_scaling_loc
        self.weak_scaling_sigma = cfg.weak_scaling_sigma
        self.strong_scaling_loc = cfg.strong_scaling_loc
        self.strong_scaling_sigma = cfg.strong_scaling_sigma
        self.strong_permute_max_segments = cfg.strong_permute_max_segments

    def __call__(self, X):
        
        X = X.transpose(1, 0) # (feat_dim, seq_length) array
        weak = jitter(scaling(X, loc = self.weak_scaling_loc, sigma= self.weak_scaling_sigma), sigma= self.weak_jitter_sigma)
        strong = scaling(permutation(X, max_segments= self.strong_permute_max_segments), loc = self.strong_scaling_loc, sigma= self.strong_scaling_sigma)
        
        weak = weak.transpose(1, 0) # (seq_length, feat_dim) array
        strong =  strong.transpose(1, 0) # (seq_length, feat_dim) array
        X = X.transpose(1, 0)
        
        mask_weak = noise_mask(weak, self.masking_ratio, self.mean_mask_length)  # (seq_length, feat_dim) boolean array
        mask_strong = noise_mask(strong, self.masking_ratio, self.mean_mask_length) # (seq_length, feat_dim) boolean array
        
        
        X_weak, target_masks_weak = torch.FloatTensor(weak), torch.BoolTensor(mask_weak)
        X_strong, target_masks_strong = torch.FloatTensor(strong), torch.BoolTensor(mask_strong)
        
        targets_weak = X_weak.clone()
        X_weak = X_weak * target_masks_weak  # mask input
        X_weak = compensate_masking(X_weak, target_masks_weak)
            
        targets_strong = X_strong.clone()
        X_strong = X_strong * target_masks_strong  
        X_strong = compensate_masking(X_strong, target_masks_strong)

        target_masks_weak = ~target_masks_weak  # inverse logic: 0 now means ignore, 1 means predict
        target_masks_strong = ~target_masks_strong
        
        return X_weak, targets_weak, target_masks_weak, X_strong, targets_strong, target_masks_strong

def noise_mask(X, masking_ratio, lm=3):

    mask = np.tile(np.expand_dims(geom_noise_mask_single(X.shape[0], lm, masking_ratio), 1), X.shape[1])

    return mask

def geom_noise_mask_single(L, lm, masking_ratio):

    keep_mask = np.ones(L, dtype=bool)
    p_m = 1 / lm  # probability of each masking sequence stopping. parameter of geometric distribution.
    p_u = p_m * masking_ratio / (1 - masking_ratio)  # probability of each unmasked sequence stopping. parameter of geometric distribution.
    p = [p_m, p_u]

    # Start in state 0 with masking_ratio probability
    state = int(np.random.rand() > masking_ratio)  # state 0 means masking, 1 means not masking
    for i in range(L):
        keep_mask[i] = state  # here it happens that state and masking value corresponding to state are identical
        if np.random.rand() < p[state]:
            state = 1 - state

    return keep_mask

def compensate_masking(X, mask):

    # number of unmasked elements of feature vector for each time step
    num_active = torch.sum(mask, dim=-1).unsqueeze(-1)  # (batch_size, seq_length, 1)
    # to avoid division by 0, set the minimum to 1
    num_active = torch.max(num_active, torch.ones(num_active.shape, dtype=torch.int16))  # (batch_size, seq_length, 1)
    return X.shape[-1] * X / num_active

def jitter(x, sigma): #0.08
    # https://arxiv.org/pdf/1706.00527.pdf
    return x + np.random.normal(loc=0., scale=sigma, size=x.shape)

def scaling(x, loc, sigma): #0.1
    # https://arxiv.org/pdf/1706.00527.pdf
    factor = np.random.normal(loc=loc, scale=sigma, size=(1, x.shape[1]))
 
    return x * factor

def permutation(x, max_segments):
    orig_steps = np.arange(x.shape[1])

    num_segs = np.random.randint(1, max_segments)

    if num_segs > 1:
        split_points = np.random.choice(x.shape[1] - 2, num_segs - 1, replace=False)
        split_points.sort()
        splits = np.split(orig_steps, split_points)

        warp = np.concatenate(np.random.permutation(splits)).ravel()
        return x[:, warp]
    else:
        return x
    
def make_rieth_imbalance(train_mask, simulate_cluster_reduction = False):
    # make rieth_tep imbalance: 500 normal runs and 5 runs for each fault
    train_runs = train_mask[train_mask].index.get_level_values(0).unique()

    if simulate_cluster_reduction:
        imbalance_train_runs = list(train_runs[:25]) + list(train_runs[500:600])
    else:
        imbalance_train_runs = train_runs[:600]

    imbalance_train_mask = train_mask.copy()
    imbalance_train_mask.loc[:] = False
    imbalance_train_mask.loc[imbalance_train_runs] = True
    return imbalance_train_mask

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier

# 1) First, when you run your model over the test set, *collect each window’s* full residuals:
all_error_windows = []
all_window_labels = []

for i in range(len(test_dl) - 1):
    ts_batch, _, target_batch, label_batch = test_dl[i]
    pred = model(ts_batch)                      # (B, W, D)
    target_np = target_batch.cpu().numpy()      # (B, W, D)
    pred_np   = pred.cpu().detach().numpy()     # (B, W, D)

    errors = target_np - pred_np                # (B, W, D)
    # We assume batch_size = 1 or that you want to treat each sample separately:
    for b in range(errors.shape[0]):
        all_error_windows.append(errors[b])     # append (W, D)
        all_window_labels.append(label_batch[b].item())

all_error_windows = np.stack(all_error_windows, axis=0)  # (N_windows, W, D)
all_window_labels = np.array(all_window_labels)          # (N_windows,)

# 2) Split into train / val for the *classifier‑on‑errors*:
X_train_w, X_val_w, y_train, y_val = train_test_split(
    all_error_windows, all_window_labels,
    test_size=0.2, random_state=42, stratify=all_window_labels
)

# 3) Define a PyTorch Dataset that applies your Augmentor to each window:
class ResidualAugDataset(Dataset):
    def __init__(self, windows: np.ndarray, labels: np.ndarray, augmentor: Augmentor):
        """
        windows: numpy array of shape (N, W, D)
        labels:  (N,)
        augmentor: instance of your Augmentor that takes (W, D) arrays
        """
        self.windows   = windows
        self.labels    = labels
        self.augmentor = augmentor

    def __len__(self):
        return len(self.windows)

    def __getitem__(self, idx):
        # get one (W, D) window
        window = self.windows[idx]
        # run through your two‑view augmentor
        X_weak, targets_weak, mask_weak, X_strong, targets_strong, mask_strong = \
            self.augmentor(window)

        # Here you have two “corrupted” views of the same residual‑window:
        #   X_weak  : with small jitter + scaling + masking  
        #   X_strong: with stronger permute + scaling + masking
        #
        # You can choose to train your classifier on either or both.
        # For example, let’s just flatten X_strong and use that:
        X_out = X_strong.view(-1).numpy()  # shape W*D

        return X_out, self.labels[idx]

# 4) Instantiate your augmentor and dataset / loader:
#    reuse the same cfg.augmentor you used upstream!
augmentor = Augmentor(r)

train_ds = ResidualAugDataset(X_train_w, y_train, augmentor)
val_ds   = ResidualAugDataset(X_val_w,   y_val,   augmentor)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=512, shuffle=False, num_workers=4, pin_memory=True)

    # you can evaluate on val_loader similarly

# 6) (Optionally) wrap them up into numpy arrays and hand over to CatBoost:
#    (you could also accumulate MANY augmented samples to feed CatBoost directly)

# flatten the entire augmented training set once:
augmented_X = []
augmented_y = []
for Xb, yb in train_loader:
    augmented_X.append(Xb.numpy())
    augmented_y.append(yb.numpy())
augmented_X = np.vstack(augmented_X)
augmented_y = np.concatenate(augmented_y)

c = CatBoostClassifier(iterations=10000,
                       early_stopping_rounds=5,
                       class_weights=(0.05, 0.95))
c.fit(augmented_X, augmented_y,
      eval_set=(augmented_X, augmented_y),
      verbose=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 66
#      62         return X_out, self.labels[idx]
#      64 # 4) Instantiate your augmentor and dataset / loader:
#      65 #    reuse the same cfg.augmentor you used upstream!
# ---> 66 augmentor = Augmentor(r)
#      68 train_ds = ResidualAugDataset(X_train_w, y_train, augmentor)
#      69 val_ds   = ResidualAugDataset(X_val_w,   y_val,   augmentor)
#
# NameError: name 'r' is not defined
